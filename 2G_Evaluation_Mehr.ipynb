# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
cc2_Before=pd.read_csv('CC2_BaseLine.csv')

# %%
cc2_Before
# Out:
#            BSC            CELL REGION         PROVINCE                 Date  \
# 0       B7611H       KZ1G0143B  South        Khuzestan  2019-06-09 21:00:00
# 1       B7611H       KZ1G0292B  South        Khuzestan  2019-06-09 22:00:00
# 2       B7611H       KZ1G0305B  South        Khuzestan  2019-06-09 22:00:00
# 3       B7611H       KZ1G0558B  South        Khuzestan  2019-06-09 13:00:00
# 4       B7611H       KZ1G0632B  South        Khuzestan  2019-06-09 10:00:00
# 5       B7611H       KZ1G0677A  South        Khuzestan  2019-06-09 20:00:00
# 6       B7611H       KZ1G0689C  South        Khuzestan  2019-06-09 22:00:00
# 7       B7611H       KZ1G0695C  South        Khuzestan  2019-06-09 21:00:00
# 8       B7611H       KZ1G1263B  South        Khuzestan  2019-06-09 22:00:00
# 9       B7612H       KZ1G0103B  South        Khuzestan  2019-06-09 12:00:00
# 10      B7612H       KZ1G0117A  South        Khuzestan  2019-06-09 18:00:00
# ...

# %%
cc2_Before['RX-Quality']=(cc2_Before['RxQuality_UL']+cc2_Before['RxQuality_DL'])/2

# %%
cc2_Before['HOSR']=(cc2_Before['IHSR']+cc2_Before['OHSR'])/2

# %%
cc2_Before.drop(columns=['IHSR','OHSR','RxQuality_UL','RxQuality_DL'],inplace=True)

# %%
cc2_Before['TCH_Ass_FR'] = cc2_Before['TCH_Assignment_FR'] - cc2_Before['TCH_Cong_Rate']

# %%
cc2_Before['Vendor']=cc2_Before['BSC'].str[-1:]

# %%
cc2_Before.describe()
# Out:
#        TCH_Traffic_BH  Available_TCH   HTCH_Traffic      SDCCH_MHT  \
# count   878638.000000  878638.000000  878638.000000  878349.000000
# mean        14.191688      25.748430       7.747053       4.278251
# std         12.904193      15.372228      11.850252       2.358128
# min          0.001000       0.000000       0.000000       0.000000
# 25%          5.338000      13.000000       0.161000       3.616000
# 50%         10.636000      22.118000       2.853000       4.104000
# 75%         19.056000      34.387500      10.361000       4.689000
# max        376.011000     168.775000     188.751000    1346.187000
#
#        TCH_Availability    AMRFR_Usage    AMRHR_Usage       CSSR_MCI  \
# count     878638.000000  878628.000000  878628.000000  877942.000000
# mean          99.824710      61.097726      37.733709      98.921192
# std            2.731122      36.605324      36.384820      39.988067
# min            0.000000       0.000000       0.000000  -23644.928000
# ...

# %%
Cell_Vendor=cc2_Before.drop(columns=list(cc2_Before.columns)[2:22])

# %%
Cell_Vendor
# Out:
#            BSC            CELL Vendor
# 0       B7611H       KZ1G0143B      H
# 1       B7611H       KZ1G0292B      H
# 2       B7611H       KZ1G0305B      H
# 3       B7611H       KZ1G0558B      H
# 4       B7611H       KZ1G0632B      H
# 5       B7611H       KZ1G0677A      H
# 6       B7611H       KZ1G0689C      H
# 7       B7611H       KZ1G0695C      H
# 8       B7611H       KZ1G1263B      H
# 9       B7612H       KZ1G0103B      H
# 10      B7612H       KZ1G0117A      H
# 11      B7612H       KZ1G0250A      H
# 12      B7612H       KZ1G0262B      H
# 13      B7612H       KZ1G0268C      H
# 14      B7612H       KZ1G0272A      H
# 15      B7612H       KZ1G0349A      H
# 16      B7612H       KZ1G0361C      H
# 17      B7612H       KZ1G0369A      H
# 18      B7612H       KZ1G0369B      H
# 19      B7612H       KZ1G0394B      H
# 20      B7612H       KZ1G0429C      H
# 21      B7611H       KZ1G0685A      H
# 22      B7611H       KZ1G0878A      H
# 23      B7611H       KZ1G0944A      H
# ...

# %%
Cell_Vendor.drop_duplicates(inplace=True)

# %% [markdown]
# # Cleaning

# %%
cc2_Before=cc2_Before[cc2_Before['TCH_Availability']>90]

# %%
cc2_Before.iloc[:,9:22]=cc2_Before.iloc[:,9:22].apply(lambda x: [100 if y>100 else y for y in x])
cc2_Before[cc2_Before.iloc[:,9:21]<0]=np.nan
cc2_Before.iloc[:,21:22]=cc2_Before.iloc[:,21:22].apply(lambda x: [0 if y<0 else y for y in x])
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\frame.py:3163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
cc2_Before.describe()
# Out:
#        TCH_Traffic_BH  Available_TCH   HTCH_Traffic      SDCCH_MHT  \
# count   859768.000000  859768.000000  859768.000000  859499.000000
# mean        14.349441      26.007229       7.803990       4.255256
# std         12.942971      15.400446      11.929608       2.331958
# min          0.001000       1.346000       0.000000       0.000000
# 25%          5.461000      13.000000       0.156000       3.608000
# 50%         10.819000      23.000000       2.836000       4.093000
# 75%         19.267000      35.000000      10.483000       4.665000
# max        376.011000     168.775000     188.751000    1346.187000
#
#        TCH_Availability    AMRFR_Usage    AMRHR_Usage       CSSR_MCI  \
# count     859768.000000  859761.000000  859761.000000  859113.000000
# mean          99.978167      61.631483      37.237079      99.129396
# std            0.311269      36.411281      36.190385       3.465260
# min           90.007000       0.000000       0.000000       0.000000
# ...

# %%
cc2_Before['Index']=cc2_Before['CELL'].str[:2]
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cc2_Before['Vendor'].replace(to_replace='W',value='H',inplace=True)
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %% [markdown]
# # After

# %%
cc2_After=pd.read_csv('CC2_Mehr.csv')

# %%
cc2_After
# Out:
#            BSC       CELL  REGION         PROVINCE                 Date  \
# 0       B7872H  KD1G0305A    West        Kordestan  2019-10-02 19:00:00
# 1       B7251H  QM1G0133A  Center              Qom  2019-10-02 11:00:00
# 2       B7311H  ES1G1629A  Center          Esfahan  2019-10-02 18:00:00
# 3       B7314H  ES1G0293A  Center          Esfahan  2019-10-02 19:00:00
# 4       B7411H  AS1G1022A    West  East Azarbaijan  2019-10-02 19:00:00
# 5       B7661H  LN1G0231C   South         Lorestan  2019-10-02 19:00:00
# 6       B7661H  LN1G0623B   South         Lorestan  2019-10-02 19:00:00
# 7       B5416H  AS1G0837A    West  East Azarbaijan  2019-10-02 12:00:00
# 8       B5445H  AG1G0881A    West  West Azarbaijan  2019-10-02 10:00:00
# 9       B7872H  KD1G0102B    West        Kordestan  2019-10-02 11:00:00
# 10      B5832H  KS5G4027B    West       Kermanshah  2019-10-02 18:00:00
# 11      B7312H  ES5G2007B  Center          Esfahan  2019-10-02 11:00:00
# ...

# %%
cc2_After['RX-Quality']=(cc2_After['RxQuality_UL']+cc2_After['RxQuality_DL'])/2
cc2_After['HOSR']=(cc2_After['IHSR']+cc2_After['OHSR'])/2
cc2_After.drop(columns=['IHSR','OHSR','RxQuality_UL','RxQuality_DL'],inplace=True)
cc2_After['TCH_Ass_FR'] = cc2_After['TCH_Assignment_FR'] - cc2_After['TCH_Cong_Rate']

# %%
cc2_After=cc2_After[cc2_After['TCH_Availability']>90]

# %%
cc2_After.iloc[:,9:22]=cc2_After.iloc[:,9:22].apply(lambda x: [100 if y>100 else y for y in x])
cc2_After[cc2_After.iloc[:,9:21]<0]=np.nan
cc2_After.iloc[:,21:22]=cc2_After.iloc[:,21:22].apply(lambda x: [0 if y<0 else y for y in x])
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\frame.py:3163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
cc2_After.describe()
# Out:
#        TCH_Traffic_BH  Available_TCH   HTCH_Traffic      SDCCH_MHT  \
# count   890336.000000  890336.000000  890336.000000  890081.000000
# mean        13.818730      25.781015       7.428846       4.281960
# std         12.472916      15.248038      11.661963       4.409683
# min          0.001000       1.257000       0.000000       0.000000
# 25%          5.136000      13.000000       0.111000       3.658000
# 50%         10.319000      22.428000       2.494000       4.130000
# 75%         18.611000      34.086000       9.946250       4.685000
# max        190.983000     178.000000     184.750000    4053.600000
#
#        TCH_Availability    AMRFR_Usage    AMRHR_Usage       CSSR_MCI  \
# count     890336.000000  890329.000000  890329.000000  889775.000000
# mean          99.978573      62.947609      35.965805      99.135207
# std            0.321240      36.244142      36.018847       3.106664
# min           90.004000       0.000000       0.000000       0.000000
# ...

# %%
cc2_After['Vendor']=cc2_After['BSC'].str[-1:]
cc2_After['Index']=cc2_After['CELL'].str[:2]
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cc2_After['Vendor'].replace(to_replace='W',value='H',inplace=True)
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\generic.py:5890: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %% [markdown]
# ## Removing rows from Target which not available in BaseLine

# %% [markdown]
# ## Exclusion_WLL_BaseLine

# %%
WLL = pd.read_excel('2G_WLL_KPI_Zero.xlsx')
condition = cc2_Before['CELL'].isin(WLL['2G_WLL']) == True
cc2_Before.drop(cc2_Before[condition].index, inplace=True)
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ## Exclusion_WLL_Target

# %%
condition = cc2_After['CELL'].isin(WLL['2G_WLL']) == True
cc2_After.drop(cc2_After[condition].index, inplace=True)
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ## Exclusion_Arbaein

# %%
# Arbaein = pd.read_excel('2G_Arbaein_Cells.xlsx')
# condition = cc2_After['CELL'].isin(Arbaein['2G_Arbaeen_Cells']) == True
# cc2_After.drop(cc2_After[condition].index, inplace=True)

# %% [markdown]
# # Averaging

# %%
cc2_Before_Avg=cc2_Before.groupby('CELL')[cc2_Before.columns[5:]].mean()

# %%
cc2_Before_Avg.describe()
# Out:
#        TCH_Traffic_BH  Available_TCH  HTCH_Traffic     SDCCH_MHT  \
# count    61735.000000   61735.000000  61735.000000  61731.000000
# mean        14.330854      25.978559      7.796570      4.260138
# std         12.253077      15.322898     11.376926      1.074098
# min          0.003500       2.000000      0.000000      0.000000
# 25%          5.679607      13.000000      0.349750      3.674036
# 50%         11.037000      23.013714      3.214714      4.122071
# 75%         19.356643      34.981750     10.549857      4.641786
# max        160.312643     167.704643    155.837357     99.252500
#
#        TCH_Availability   AMRFR_Usage   AMRHR_Usage      CSSR_MCI  \
# count      61735.000000  61735.000000  61735.000000  61728.000000
# mean          99.977088     61.566605     37.278310     99.112291
# std            0.128424     35.076940     34.865796      2.491443
# min           94.799400      0.000000      0.000000      0.000000
# ...

# %%
cc2_Before_Avg=pd.merge(cc2_Before_Avg,Cell_Vendor,on='CELL',how='left')
cc2_Before_Avg['Index']=cc2_Before_Avg['CELL'].str[:2]

# %%
cc2_Before_Avg
# Out:
#             CELL  TCH_Traffic_BH  Available_TCH  HTCH_Traffic  SDCCH_MHT  \
# 0      AG1G0001A       10.915500      27.166357      0.009714   4.379214
# 1      AG1G0001B       21.532429      37.811214     15.355571   4.492143
# 2      AG1G0001C       29.267429      35.783286     29.014500   4.560929
# 3      AG1G0002A       26.236857      56.344714      1.047071   4.243714
# 4      AG1G0002B       67.179500      87.545786     63.716286   4.336071
# 5      AG1G0002C       20.144929      41.817643      1.061429   4.292214
# 6      AG1G0003A       19.654214      44.094643      0.102857   4.975786
# 7      AG1G0003B       28.823143      51.575071     14.243357   4.513643
# 8      AG1G0003C       15.835929      30.162786      8.204357   4.732214
# 9      AG1G0004A       22.335571      44.903929     19.586571   5.114571
# 10     AG1G0004B       35.411071      56.360429     33.506071   4.821286
# 11     AG1G0004C       14.759214      65.833429      8.278214   4.899857
# ...

# %%
cc2_Before_Avg['Vendor'].value_counts()
# Out:
# H    23257
# N    22901
# E    15521
# W       59
# Name: Vendor, dtype: int64

# %%
cc2_After_Avg=cc2_After.groupby('CELL')[cc2_After.columns[5:]].mean()

# %%
cc2_After_Avg.reset_index(inplace=True)
cc2_After_Avg['Index']=cc2_After_Avg['CELL'].str[:2]

# %% [markdown]
# # CDR

# %%
CDR_H=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='H']['CDR']
CDR_H = CDR_H.sort_values().reset_index(drop = True)
CDR_H=CDR_H[(CDR_H>=0)&(CDR_H<=100)]
#################################################
CDR_N=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='N']['CDR']
CDR_N = CDR_N.sort_values().reset_index(drop = True)
CDR_N=CDR_N[(CDR_N>=0)&(CDR_N<=100)]
########################################
CDR_E=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='E']['CDR']
CDR_E = CDR_E.sort_values().reset_index(drop = True)
CDR_E=CDR_E[(CDR_E>=0)&(CDR_E<=100)]

# %%
CDR_H_Th1=(CDR_H[np.floor(len(CDR_H)*0.2)]+CDR_H[np.floor(len(CDR_H)*0.2)+1])/2
CDR_H_Th2=(CDR_H[np.floor(len(CDR_H)*0.5)]+CDR_H[np.floor(len(CDR_H)*0.5)+1])/2
CDR_H_Th3=(CDR_H[np.floor(len(CDR_H)*0.75)]+CDR_H[np.floor(len(CDR_H)*0.75)+1])/2
CDR_H_Th4=(CDR_H[np.floor(len(CDR_H)*0.90)]+CDR_H[np.floor(len(CDR_H)*0.90)+1])/2
#####################################################################################
CDR_N_Th1=(CDR_N[np.floor(len(CDR_N)*0.2)]+CDR_N[np.floor(len(CDR_N)*0.2)+1])/2
CDR_N_Th2=(CDR_N[np.floor(len(CDR_N)*0.5)]+CDR_N[np.floor(len(CDR_N)*0.5)+1])/2
CDR_N_Th3=(CDR_N[np.floor(len(CDR_N)*0.75)]+CDR_N[np.floor(len(CDR_N)*0.75)+1])/2
CDR_N_Th4=(CDR_N[np.floor(len(CDR_N)*0.90)]+CDR_N[np.floor(len(CDR_N)*0.90)+1])/2
#####################################################################################
CDR_E_Th1=(CDR_E[np.floor(len(CDR_E)*0.2)]+CDR_E[np.floor(len(CDR_E)*0.2)+1])/2
CDR_E_Th2=(CDR_E[np.floor(len(CDR_E)*0.5)]+CDR_E[np.floor(len(CDR_E)*0.5)+1])/2
CDR_E_Th3=(CDR_E[np.floor(len(CDR_E)*0.75)]+CDR_E[np.floor(len(CDR_E)*0.75)+1])/2
CDR_E_Th4=(CDR_E[np.floor(len(CDR_E)*0.90)]+CDR_E[np.floor(len(CDR_E)*0.90)+1])/2

# %% [markdown]
# # TCH_Cong

# %%
TCH_Cong_H=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='H']['TCH_Cong_Rate']
TCH_Cong_H = TCH_Cong_H.sort_values().reset_index(drop = True)
TCH_Cong_H=TCH_Cong_H[(TCH_Cong_H>=0)&(TCH_Cong_H<=100)]
#################################################
TCH_Cong_N=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='N']['TCH_Cong_Rate']
TCH_Cong_N = TCH_Cong_N.sort_values().reset_index(drop = True)
TCH_Cong_N=TCH_Cong_N[(TCH_Cong_N>=0)&(TCH_Cong_N<=100)]
########################################
TCH_Cong_E=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='E']['TCH_Cong_Rate']
TCH_Cong_E = TCH_Cong_E.sort_values().reset_index(drop = True)
TCH_Cong_E=TCH_Cong_E[(TCH_Cong_E>=0)&(TCH_Cong_E<=100)]

# %%
zcph = (len(TCH_Cong_H) - np.count_nonzero(TCH_Cong_H))/len(TCH_Cong_H)
zcpn = (len(TCH_Cong_N) - np.count_nonzero(TCH_Cong_N))/len(TCH_Cong_N)
zcpe = (len(TCH_Cong_E) - np.count_nonzero(TCH_Cong_E))/len(TCH_Cong_E)
zcp = [zcph, zcpn, zcpe]
per = max(zcp)
per2 = (0.3*(1-per)/0.8)+per
per3 = (0.25*(1-per)/0.8)+per2
per4 = (0.15*(1-per)/0.8)+per3
print(0.2 < per < 0.5)
# Out:
# False

# %%
print(per, per2, per3, per4)
# Out:
# 0.8751852567820092 0.9219907854887558 0.960995392744378 0.9843981570977512

# %%
TCH_Cong_H_Th1=(TCH_Cong_H[np.floor(len(TCH_Cong_H)*per)]+TCH_Cong_H[np.floor(len(TCH_Cong_H)*per)+1])/2
TCH_Cong_H_Th2=(TCH_Cong_H[np.floor(len(TCH_Cong_H)*per2)]+TCH_Cong_H[np.floor(len(TCH_Cong_H)*per2)+1])/2
TCH_Cong_H_Th3=(TCH_Cong_H[np.floor(len(TCH_Cong_H)*per3)]+TCH_Cong_H[np.floor(len(TCH_Cong_H)*per3)+1])/2
TCH_Cong_H_Th4=(TCH_Cong_H[np.floor(len(TCH_Cong_H)*per4)]+TCH_Cong_H[np.floor(len(TCH_Cong_H)*per4)+1])/2
#####################################################################################
TCH_Cong_N_Th1=(TCH_Cong_N[np.floor(len(TCH_Cong_N)*per)]+TCH_Cong_N[np.floor(len(TCH_Cong_N)*per)+1])/2
TCH_Cong_N_Th2=(TCH_Cong_N[np.floor(len(TCH_Cong_N)*per2)]+TCH_Cong_N[np.floor(len(TCH_Cong_N)*per2)+1])/2
TCH_Cong_N_Th3=(TCH_Cong_N[np.floor(len(TCH_Cong_N)*per3)]+TCH_Cong_N[np.floor(len(TCH_Cong_N)*per3)+1])/2
TCH_Cong_N_Th4=(TCH_Cong_N[np.floor(len(TCH_Cong_N)*per4)]+TCH_Cong_N[np.floor(len(TCH_Cong_N)*per4)+1])/2
#####################################################################################
TCH_Cong_E_Th1=(TCH_Cong_E[np.floor(len(TCH_Cong_E)*per)]+TCH_Cong_E[np.floor(len(TCH_Cong_E)*per)+1])/2
TCH_Cong_E_Th2=(TCH_Cong_E[np.floor(len(TCH_Cong_E)*per2)]+TCH_Cong_E[np.floor(len(TCH_Cong_E)*per2)+1])/2
TCH_Cong_E_Th3=(TCH_Cong_E[np.floor(len(TCH_Cong_E)*per3)]+TCH_Cong_E[np.floor(len(TCH_Cong_E)*per3)+1])/2
TCH_Cong_E_Th4=(TCH_Cong_E[np.floor(len(TCH_Cong_E)*per4)]+TCH_Cong_E[np.floor(len(TCH_Cong_E)*per4)+1])/2

# %% [markdown]
# # TCH_Ass_FR

# %%
TAFR_H=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='H']['TCH_Ass_FR']
TAFR_H = TAFR_H.sort_values().reset_index(drop = True)
TAFR_H=TAFR_H[(TAFR_H>=0)&(TAFR_H<=100)]
#################################################
TAFR_N=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='N']['TCH_Ass_FR']
TAFR_N = TAFR_N.sort_values().reset_index(drop = True)
TAFR_N=TAFR_N[(TAFR_N>=0)&(TAFR_N<=100)]
########################################
TAFR_E=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='E']['TCH_Ass_FR']
TAFR_E = TAFR_E.sort_values().reset_index(drop = True)
TAFR_E=TAFR_E[(TAFR_E>=0)&(TAFR_E<=100)]

# %%
TAFR_H_Th1=(TAFR_H[np.floor(len(TAFR_H)*0.2)]+TAFR_H[np.floor(len(TAFR_H)*0.2)+1])/2
TAFR_H_Th2=(TAFR_H[np.floor(len(TAFR_H)*0.5)]+TAFR_H[np.floor(len(TAFR_H)*0.5)+1])/2
TAFR_H_Th3=(TAFR_H[np.floor(len(TAFR_H)*0.75)]+TAFR_H[np.floor(len(TAFR_H)*0.75)+1])/2
TAFR_H_Th4=(TAFR_H[np.floor(len(TAFR_H)*0.90)]+TAFR_H[np.floor(len(TAFR_H)*0.90)+1])/2
#####################################################################################
TAFR_N_Th1=(TAFR_N[np.floor(len(TAFR_N)*0.2)]+TAFR_N[np.floor(len(TAFR_N)*0.2)+1])/2
TAFR_N_Th2=(TAFR_N[np.floor(len(TAFR_N)*0.5)]+TAFR_N[np.floor(len(TAFR_N)*0.5)+1])/2
TAFR_N_Th3=(TAFR_N[np.floor(len(TAFR_N)*0.75)]+TAFR_N[np.floor(len(TAFR_N)*0.75)+1])/2
TAFR_N_Th4=(TAFR_N[np.floor(len(TAFR_N)*0.90)]+TAFR_N[np.floor(len(TAFR_N)*0.90)+1])/2
#####################################################################################
TAFR_E_Th1=(TAFR_E[np.floor(len(TAFR_E)*0.2)]+TAFR_E[np.floor(len(TAFR_E)*0.2)+1])/2
TAFR_E_Th2=(TAFR_E[np.floor(len(TAFR_E)*0.5)]+TAFR_E[np.floor(len(TAFR_E)*0.5)+1])/2
TAFR_E_Th3=(TAFR_E[np.floor(len(TAFR_E)*0.75)]+TAFR_E[np.floor(len(TAFR_E)*0.75)+1])/2
TAFR_E_Th4=(TAFR_E[np.floor(len(TAFR_E)*0.90)]+TAFR_E[np.floor(len(TAFR_E)*0.90)+1])/2

# %% [markdown]
# # SD_Drop

# %%
SD_Drop_H=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='H']['SDCCH_Drop_Rate']
SD_Drop_H = SD_Drop_H.sort_values().reset_index(drop = True)
SD_Drop_H=SD_Drop_H[(SD_Drop_H>=0)&(SD_Drop_H<=100)]
#################################################
SD_Drop_N=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='N']['SDCCH_Drop_Rate']
SD_Drop_N = SD_Drop_N.sort_values().reset_index(drop = True)
SD_Drop_N=SD_Drop_N[(SD_Drop_N>=0)&(SD_Drop_N<=100)]
########################################
SD_Drop_E=cc2_Before[cc2_Before['Vendor']=='E']['SDCCH_Drop_Rate']
SD_Drop_E = SD_Drop_E.sort_values().reset_index(drop = True)
SD_Drop_E=SD_Drop_E[(SD_Drop_E>=0)&(SD_Drop_E<=100)]

# %%
SD_Drop_H_Th1=(SD_Drop_H[np.floor(len(SD_Drop_H)*0.2)]+SD_Drop_H[np.floor(len(SD_Drop_H)*0.2)+1])/2
SD_Drop_H_Th2=(SD_Drop_H[np.floor(len(SD_Drop_H)*0.5)]+SD_Drop_H[np.floor(len(SD_Drop_H)*0.5)+1])/2
SD_Drop_H_Th3=(SD_Drop_H[np.floor(len(SD_Drop_H)*0.75)]+SD_Drop_H[np.floor(len(SD_Drop_H)*0.75)+1])/2
SD_Drop_H_Th4=(SD_Drop_H[np.floor(len(SD_Drop_H)*0.90)]+SD_Drop_H[np.floor(len(SD_Drop_H)*0.90)+1])/2
#####################################################################################
SD_Drop_N_Th1=(SD_Drop_N[np.floor(len(SD_Drop_N)*0.2)]+SD_Drop_N[np.floor(len(SD_Drop_N)*0.2)+1])/2
SD_Drop_N_Th2=(SD_Drop_N[np.floor(len(SD_Drop_N)*0.5)]+SD_Drop_N[np.floor(len(SD_Drop_N)*0.5)+1])/2
SD_Drop_N_Th3=(SD_Drop_N[np.floor(len(SD_Drop_N)*0.75)]+SD_Drop_N[np.floor(len(SD_Drop_N)*0.75)+1])/2
SD_Drop_N_Th4=(SD_Drop_N[np.floor(len(SD_Drop_N)*0.90)]+SD_Drop_N[np.floor(len(SD_Drop_N)*0.90)+1])/2
#####################################################################################
SD_Drop_E_Th1=(SD_Drop_E[np.floor(len(SD_Drop_E)*0.2)]+SD_Drop_E[np.floor(len(SD_Drop_E)*0.2)+1])/2
SD_Drop_E_Th2=(SD_Drop_E[np.floor(len(SD_Drop_E)*0.5)]+SD_Drop_E[np.floor(len(SD_Drop_E)*0.5)+1])/2
SD_Drop_E_Th3=(SD_Drop_E[np.floor(len(SD_Drop_E)*0.75)]+SD_Drop_E[np.floor(len(SD_Drop_E)*0.75)+1])/2
SD_Drop_E_Th4=(SD_Drop_E[np.floor(len(SD_Drop_E)*0.90)]+SD_Drop_E[np.floor(len(SD_Drop_E)*0.90)+1])/2

# %% [markdown]
# # Rx-Qual

# %%
Rx_Qual_H=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='H']['RX-Quality']
Rx_Qual_H = Rx_Qual_H.sort_values(ascending=False).reset_index(drop = True)
Rx_Qual_H=Rx_Qual_H[(Rx_Qual_H>=0)&(Rx_Qual_H<=100)]
#################################################
Rx_Qual_N=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='N']['RX-Quality']
Rx_Qual_N = Rx_Qual_N.sort_values(ascending=False).reset_index(drop = True)
Rx_Qual_N=Rx_Qual_N[(Rx_Qual_N>=0)&(Rx_Qual_N<=100)]
########################################
Rx_Qual_E=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='E']['RX-Quality']
Rx_Qual_E = Rx_Qual_E.sort_values(ascending=False).reset_index(drop = True)
Rx_Qual_E=Rx_Qual_E[(Rx_Qual_E>=0)&(Rx_Qual_E<=100)]

# %%
Rx_Qual_H_Th1=(Rx_Qual_H[np.floor(len(Rx_Qual_H)*0.2)]+Rx_Qual_H[np.floor(len(Rx_Qual_H)*0.2)+1])/2
Rx_Qual_H_Th2=(Rx_Qual_H[np.floor(len(Rx_Qual_H)*0.5)]+Rx_Qual_H[np.floor(len(Rx_Qual_H)*0.5)+1])/2
Rx_Qual_H_Th3=(Rx_Qual_H[np.floor(len(Rx_Qual_H)*0.75)]+Rx_Qual_H[np.floor(len(Rx_Qual_H)*0.75)+1])/2
Rx_Qual_H_Th4=(Rx_Qual_H[np.floor(len(Rx_Qual_H)*0.90)]+Rx_Qual_H[np.floor(len(Rx_Qual_H)*0.90)+1])/2
#####################################################################################
Rx_Qual_N_Th1=(Rx_Qual_N[np.floor(len(Rx_Qual_N)*0.2)]+Rx_Qual_N[np.floor(len(Rx_Qual_N)*0.2)+1])/2
Rx_Qual_N_Th2=(Rx_Qual_N[np.floor(len(Rx_Qual_N)*0.5)]+Rx_Qual_N[np.floor(len(Rx_Qual_N)*0.5)+1])/2
Rx_Qual_N_Th3=(Rx_Qual_N[np.floor(len(Rx_Qual_N)*0.75)]+Rx_Qual_N[np.floor(len(Rx_Qual_N)*0.75)+1])/2
Rx_Qual_N_Th4=(Rx_Qual_N[np.floor(len(Rx_Qual_N)*0.90)]+Rx_Qual_N[np.floor(len(Rx_Qual_N)*0.90)+1])/2
#####################################################################################
Rx_Qual_E_Th1=(Rx_Qual_E[np.floor(len(Rx_Qual_E)*0.2)]+Rx_Qual_E[np.floor(len(Rx_Qual_E)*0.2)+1])/2
Rx_Qual_E_Th2=(Rx_Qual_E[np.floor(len(Rx_Qual_E)*0.5)]+Rx_Qual_E[np.floor(len(Rx_Qual_E)*0.5)+1])/2
Rx_Qual_E_Th3=(Rx_Qual_E[np.floor(len(Rx_Qual_E)*0.75)]+Rx_Qual_E[np.floor(len(Rx_Qual_E)*0.75)+1])/2
Rx_Qual_E_Th4=(Rx_Qual_E[np.floor(len(Rx_Qual_E)*0.90)]+Rx_Qual_E[np.floor(len(Rx_Qual_E)*0.90)+1])/2

# %% [markdown]
# # HOSR

# %%
HOSR_H=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='H']['HOSR']
HOSR_H = HOSR_H.sort_values(ascending=False).reset_index(drop = True)
HOSR_H=HOSR_H[(HOSR_H>=0)&(HOSR_H<=100)]
#################################################
HOSR_N=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='N']['HOSR']
HOSR_N = HOSR_N.sort_values(ascending=False).reset_index(drop = True)
HOSR_N=HOSR_N[(HOSR_N>=0)&(HOSR_N<=100)]
########################################
HOSR_E=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='E']['HOSR']
HOSR_E = HOSR_E.sort_values(ascending=False).reset_index(drop = True)
HOSR_E=HOSR_E[(HOSR_E>=0)&(HOSR_E<=100)]

# %%
HOSR_H_Th1=(HOSR_H[np.floor(len(HOSR_H)*0.2)]+HOSR_H[np.floor(len(HOSR_H)*0.2)+1])/2
HOSR_H_Th2=(HOSR_H[np.floor(len(HOSR_H)*0.5)]+HOSR_H[np.floor(len(HOSR_H)*0.5)+1])/2
HOSR_H_Th3=(HOSR_H[np.floor(len(HOSR_H)*0.75)]+HOSR_H[np.floor(len(HOSR_H)*0.75)+1])/2
HOSR_H_Th4=(HOSR_H[np.floor(len(HOSR_H)*0.90)]+HOSR_H[np.floor(len(HOSR_H)*0.90)+1])/2
#####################################################################################
HOSR_N_Th1=(HOSR_N[np.floor(len(HOSR_N)*0.2)]+HOSR_N[np.floor(len(HOSR_N)*0.2)+1])/2
HOSR_N_Th2=(HOSR_N[np.floor(len(HOSR_N)*0.5)]+HOSR_N[np.floor(len(HOSR_N)*0.5)+1])/2
HOSR_N_Th3=(HOSR_N[np.floor(len(HOSR_N)*0.75)]+HOSR_N[np.floor(len(HOSR_N)*0.75)+1])/2
HOSR_N_Th4=(HOSR_N[np.floor(len(HOSR_N)*0.90)]+HOSR_N[np.floor(len(HOSR_N)*0.90)+1])/2
#####################################################################################
HOSR_E_Th1=(HOSR_E[np.floor(len(HOSR_E)*0.2)]+HOSR_E[np.floor(len(HOSR_E)*0.2)+1])/2
HOSR_E_Th2=(HOSR_E[np.floor(len(HOSR_E)*0.5)]+HOSR_E[np.floor(len(HOSR_E)*0.5)+1])/2
HOSR_E_Th3=(HOSR_E[np.floor(len(HOSR_E)*0.75)]+HOSR_E[np.floor(len(HOSR_E)*0.75)+1])/2
HOSR_E_Th4=(HOSR_E[np.floor(len(HOSR_E)*0.90)]+HOSR_E[np.floor(len(HOSR_E)*0.90)+1])/2

# %% [markdown]
# # SD_ASS_SR

# %%
SD_ASS_SR_H=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='H']['SDCCH_Access_Success_Rate']
SD_ASS_SR_H = SD_ASS_SR_H.sort_values(ascending=False).reset_index(drop = True)
SD_ASS_SR_H=SD_ASS_SR_H[(SD_ASS_SR_H>=0)&(SD_ASS_SR_H<=100)]
#################################################
SD_ASS_SR_N=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='N']['SDCCH_Access_Success_Rate']
SD_ASS_SR_N = SD_ASS_SR_N.sort_values(ascending=False).reset_index(drop = True)
SD_ASS_SR_N=SD_ASS_SR_N[(SD_ASS_SR_N>=0)&(SD_ASS_SR_N<=100)]
########################################
SD_ASS_SR_E=cc2_Before_Avg[cc2_Before_Avg['Vendor']=='E']['SDCCH_Access_Success_Rate']
SD_ASS_SR_E = SD_ASS_SR_E.sort_values(ascending=False).reset_index(drop = True)
SD_ASS_SR_E=SD_ASS_SR_E[(SD_ASS_SR_E>=0)&(SD_ASS_SR_E<=100)]

# %%
SD_ASS_SR_H_Th1=(SD_ASS_SR_H[np.floor(len(SD_ASS_SR_H)*0.2)]+SD_ASS_SR_H[np.floor(len(SD_ASS_SR_H)*0.2)+1])/2
SD_ASS_SR_H_Th2=(SD_ASS_SR_H[np.floor(len(SD_ASS_SR_H)*0.5)]+SD_ASS_SR_H[np.floor(len(SD_ASS_SR_H)*0.5)+1])/2
SD_ASS_SR_H_Th3=(SD_ASS_SR_H[np.floor(len(SD_ASS_SR_H)*0.75)]+SD_ASS_SR_H[np.floor(len(SD_ASS_SR_H)*0.75)+1])/2
SD_ASS_SR_H_Th4=(SD_ASS_SR_H[np.floor(len(SD_ASS_SR_H)*0.90)]+SD_ASS_SR_H[np.floor(len(SD_ASS_SR_H)*0.90)+1])/2
#####################################################################################
SD_ASS_SR_N_Th1=(SD_ASS_SR_N[np.floor(len(SD_ASS_SR_N)*0.2)]+SD_ASS_SR_N[np.floor(len(SD_ASS_SR_N)*0.2)+1])/2
SD_ASS_SR_N_Th2=(SD_ASS_SR_N[np.floor(len(SD_ASS_SR_N)*0.5)]+SD_ASS_SR_N[np.floor(len(SD_ASS_SR_N)*0.5)+1])/2
SD_ASS_SR_N_Th3=(SD_ASS_SR_N[np.floor(len(SD_ASS_SR_N)*0.75)]+SD_ASS_SR_N[np.floor(len(SD_ASS_SR_N)*0.75)+1])/2
SD_ASS_SR_N_Th4=(SD_ASS_SR_N[np.floor(len(SD_ASS_SR_N)*0.90)]+SD_ASS_SR_N[np.floor(len(SD_ASS_SR_N)*0.90)+1])/2
#####################################################################################
SD_ASS_SR_E_Th1=(SD_ASS_SR_E[np.floor(len(SD_ASS_SR_E)*0.2)]+SD_ASS_SR_E[np.floor(len(SD_ASS_SR_E)*0.2)+1])/2
SD_ASS_SR_E_Th2=(SD_ASS_SR_E[np.floor(len(SD_ASS_SR_E)*0.5)]+SD_ASS_SR_E[np.floor(len(SD_ASS_SR_E)*0.5)+1])/2
SD_ASS_SR_E_Th3=(SD_ASS_SR_E[np.floor(len(SD_ASS_SR_E)*0.75)]+SD_ASS_SR_E[np.floor(len(SD_ASS_SR_E)*0.75)+1])/2
SD_ASS_SR_E_Th4=(SD_ASS_SR_E[np.floor(len(SD_ASS_SR_E)*0.90)]+SD_ASS_SR_E[np.floor(len(SD_ASS_SR_E)*0.90)+1])/2

# %% [markdown]
# ## Thresholds to DF

# %%
d = {'Threshold': ['H_TH1','H_TH2','H_TH3','H_TH4','N_TH1','N_TH2','N_TH3','N_TH4','E_TH1','E_TH2','E_TH3','E_TH4'],
     'CDR': [CDR_H_Th1, CDR_H_Th2, CDR_H_Th3, CDR_H_Th4, CDR_N_Th1, CDR_N_Th2, CDR_N_Th3, CDR_N_Th4, CDR_E_Th1, CDR_E_Th2, CDR_E_Th3, CDR_E_Th4],
     'TCH_Cong': [TCH_Cong_H_Th1, TCH_Cong_H_Th2, TCH_Cong_H_Th3, TCH_Cong_H_Th4, TCH_Cong_N_Th1, TCH_Cong_N_Th2, TCH_Cong_N_Th3, TCH_Cong_N_Th4, TCH_Cong_E_Th1, TCH_Cong_E_Th2, TCH_Cong_E_Th3, TCH_Cong_E_Th4],
     'TAFR': [TAFR_H_Th1, TAFR_H_Th2, TAFR_H_Th3, TAFR_H_Th4, TAFR_N_Th1, TAFR_N_Th2, TAFR_N_Th3, TAFR_N_Th4, TAFR_E_Th1, TAFR_E_Th2, TAFR_E_Th3, TAFR_E_Th4],
     'SD_Drop': [SD_Drop_H_Th1, SD_Drop_H_Th2, SD_Drop_H_Th3, SD_Drop_H_Th4, SD_Drop_N_Th1, SD_Drop_N_Th2, SD_Drop_N_Th3, SD_Drop_N_Th4, SD_Drop_E_Th1, SD_Drop_E_Th2, SD_Drop_E_Th3, SD_Drop_E_Th4],
     'Rx_Qual': [Rx_Qual_H_Th1, Rx_Qual_H_Th2, Rx_Qual_H_Th3, Rx_Qual_H_Th4, Rx_Qual_N_Th1, Rx_Qual_N_Th2, Rx_Qual_N_Th3, Rx_Qual_N_Th4, Rx_Qual_E_Th1, Rx_Qual_E_Th2, Rx_Qual_E_Th3, Rx_Qual_E_Th4],
     'HOSR': [HOSR_H_Th1, HOSR_H_Th2, HOSR_H_Th3, HOSR_H_Th4, HOSR_N_Th1, HOSR_N_Th2, HOSR_N_Th3, HOSR_N_Th4, HOSR_E_Th1, HOSR_E_Th2, HOSR_E_Th3, HOSR_E_Th4],
     'SD_ASS_SR': [SD_ASS_SR_H_Th1, SD_ASS_SR_H_Th2, SD_ASS_SR_H_Th3, SD_ASS_SR_H_Th4, SD_ASS_SR_N_Th1, SD_ASS_SR_N_Th2, SD_ASS_SR_N_Th3, SD_ASS_SR_N_Th4, SD_ASS_SR_E_Th1, SD_ASS_SR_E_Th2, SD_ASS_SR_E_Th3, SD_ASS_SR_E_Th4]
    }
Thresholds = pd.DataFrame(data=d)
Thresholds.to_excel('Thresholds.xlsx')

# %%
Dashboard=[]
Dashboard=cc2_Before.groupby(by=['Index','Vendor'],as_index=False).count()
Dashboard
# Out:
#    Index Vendor    BSC   CELL  REGION  PROVINCE   Date  TCH_Traffic_BH  \
# 0     AG      H  22884  22884   22884     22884  22884           22884
# 1     AG      N   2752   2752    2752      2752   2752            2752
# 2     AR      H  10174  10174   10159     10159  10174           10174
# 3     AR      N   8982   8982    8982      8982   8982            8982
# 4     AS      H  32528  32528   32525     32525  32528           32528
# 5     AS      N   5647   5647    5647      5647   5647            5647
# 6     BU      H  16147  16147   16141     16141  16147           16147
# 7     BU      N   1995   1995    1995      1995   1995            1995
# 8     CH      N  15469  15469   15469     15469  15469           15469
# 9     ES      H  56869  56869   56860     56860  56869           56869
# 10    FS      N  46595  46595   46595     46595  46595           46595
# 11    GL      E  30377  30377   30377     30377  30377           30377
# ...

# %%
Dashboard2=[]
Dashboard2=Dashboard.groupby('Index',as_index=False).sum()
# Out:
#    Index     BSC    CELL  REGION  PROVINCE    Date  TCH_Traffic_BH  \
# 0     AG   25636   25636   25636     25636   25636           25636
# 1     AR   19156   19156   19141     19141   19156           19156
# 2     AS   38175   38175   38172     38172   38175           38175
# 3     BU   18142   18142   18136     18136   18142           18142
# 4     CH   15469   15469   15469     15469   15469           15469
# 5     ES   56869   56869   56860     56860   56869           56869
# 6     FS   46595   46595   46595     46595   46595           46595
# 7     GL   30377   30377   30377     30377   30377           30377
# 8     GN   18287   18287   18287     18287   18287           18287
# 9     HN   19155   19155   19149     19149   19155           19155
# 10    HZ   28379   28379   28373     28373   28379           28379
# 11    IL    9581    9581    9581      9581    9581            9581
# 12    KB   12370   12370   12370     12370   12370           12370
# ...

# %%
Dashboard2.drop(columns=list(Dashboard2.columns)[5:12],inplace=True)

# %%
Dashboard2.drop(columns=list(Dashboard2.columns)[3:7],inplace=True)

# %%
Dashboard2.drop(columns=['BSC','SDCCH_Congestion_Rate','TCH_Assignment_FR'],inplace=True)

# %%
Dashboard2
# Out:
#    Index    CELL  SDCCH_Drop_Rate  TCH_Cong_Rate  SDCCH_Access_Success_Rate  \
# 0     AG   25636            25631          25588                      25631
# 1     AR   19156            19133          19113                      19133
# 2     AS   38175            38162          38131                      38162
# 3     BU   18142            18141          18136                      18141
# 4     CH   15469            15468          15464                      15468
# 5     ES   56869            56867          56840                      56867
# 6     FS   46595            46591          46575                      46591
# 7     GL   30377            30375          30363                      30375
# 8     GN   18287            18281          18268                      18283
# 9     HN   19155            19140          19140                      19140
# 10    HZ   28379            28339          28323                      28339
# ...

# %%
Dashboard_af=[]
Dashboard_af=cc2_After.groupby(by=['Index','Vendor'],as_index=False).count()

# %%
Dashboard2_af=Dashboard_af.groupby('Index',as_index=False).sum()

# %%
Dashboard2_af.drop(columns=list(Dashboard2_af.columns)[5:12],inplace=True)

# %%
Dashboard2_af.drop(columns=list(Dashboard2_af.columns)[3:7],inplace=True)

# %%
Dashboard2_af.drop(columns=['BSC','SDCCH_Congestion_Rate','TCH_Assignment_FR'],inplace=True)

# %%
Dashboard2_af
# Out:
#    Index    CELL  SDCCH_Drop_Rate  TCH_Cong_Rate  SDCCH_Access_Success_Rate  \
# 0     AG   26270            26267          26240                      26267
# 1     AR   19276            19266          19255                      19266
# 2     AS   38322            38286          38245                      38286
# 3     BU   18251            18251          18248                      18251
# 4     CH   15585            15585          15584                      15585
# 5     ES   57411            57401          57383                      57401
# 6     FS   50853            50852          50843                      50852
# 7     GL   30349            30349          30338                      30349
# 8     GN   18394            18364          18368                      18367
# 9     HN   20921            20921          20911                      20921
# 10    HZ   29061            29014          29003                      29014
# ...

# %%
Dashboardfinal=[]
Dashboard_Final=pd.merge(Dashboard2,Dashboard2_af,on='Index',how='left',suffixes=('_Baseline','_Target'))

# %%
Dashboard_Final=Dashboard_Final.merge(cc2_Before_Avg.groupby(by=['Index'],as_index=False)['CELL'].count(),on='Index')

# %%
Dashboard_Final=Dashboard_Final.merge(cc2_After_Avg.groupby(by=['Index'],as_index=False)['CELL'].count(),on='Index')

# %%
Dashboard_Final.rename(columns={'CELL_x':'CELL_Baseline_Unique','CELL_y':'CELL_Target_Unique'},inplace=True)

# %%
Dashboard_Final
# Out:
#    Index  CELL_Baseline  SDCCH_Drop_Rate_Baseline  TCH_Cong_Rate_Baseline  \
# 0     AG          25636                     25631                   25588
# 1     AR          19156                     19133                   19113
# 2     AS          38175                     38162                   38131
# 3     BU          18142                     18141                   18136
# 4     CH          15469                     15468                   15464
# 5     ES          56869                     56867                   56840
# 6     FS          46595                     46591                   46575
# 7     GL          30377                     30375                   30363
# 8     GN          18287                     18281                   18268
# 9     HN          19155                     19140                   19140
# 10    HZ          28379                     28339                   28323
# 11    IL           9581                      9579                    9574
# ...

# %% [markdown]
# # CDR_Dashboard_Baseline

# %%
CDR100_BaseLine=cc2_Before[((cc2_Before['CDR']<CDR_H_Th1)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['CDR']<CDR_E_Th1)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['CDR']<CDR_N_Th1)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
CDR100_BaseLine_df=pd.DataFrame(CDR100_BaseLine).reset_index()
#####################################################################
CDR90_BaseLine=(cc2_Before[((cc2_Before['CDR']<CDR_H_Th2)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['CDR']<CDR_E_Th2)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['CDR']<CDR_N_Th2)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-CDR100_BaseLine
CDR90_BaseLine_df=pd.DataFrame(CDR90_BaseLine).reset_index()
#####################################################################
CDR80_BaseLine=(cc2_Before[((cc2_Before['CDR']<CDR_H_Th3)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['CDR']<CDR_E_Th3)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['CDR']<CDR_N_Th3)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(CDR100_BaseLine+CDR90_BaseLine)
CDR80_BaseLine_df=pd.DataFrame(CDR80_BaseLine).reset_index()
#####################################################################
CDR50_BaseLine=(cc2_Before[((cc2_Before['CDR']<CDR_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['CDR']<CDR_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['CDR']<CDR_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(CDR100_BaseLine+CDR90_BaseLine+CDR80_BaseLine)
CDR50_BaseLine_df=pd.DataFrame(CDR50_BaseLine).reset_index()
#####################################################################
CDRM10_BaseLine=cc2_Before[((cc2_Before['CDR']>=CDR_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['CDR']>=CDR_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['CDR']>=CDR_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
CDRM10_BaseLine_df=pd.DataFrame(CDRM10_BaseLine).reset_index()

# %% [markdown]
# # CDR_Dashboard_Target

# %%
CDR100_Target=cc2_After[((cc2_After['CDR']<CDR_H_Th1)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['CDR']<CDR_E_Th1)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['CDR']<CDR_N_Th1)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
CDR100_Target_df=pd.DataFrame(CDR100_Target).reset_index()
#####################################################################
CDR90_Target=(cc2_After[((cc2_After['CDR']<CDR_H_Th2)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['CDR']<CDR_E_Th2)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['CDR']<CDR_N_Th2)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-CDR100_Target
CDR90_Target_df=pd.DataFrame(CDR90_Target).reset_index()
#####################################################################
CDR80_Target=(cc2_After[((cc2_After['CDR']<CDR_H_Th3)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['CDR']<CDR_E_Th3)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['CDR']<CDR_N_Th3)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(CDR100_Target+CDR90_Target)
CDR80_Target_df=pd.DataFrame(CDR80_Target).reset_index()
#####################################################################
CDR50_Target=(cc2_After[((cc2_After['CDR']<CDR_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['CDR']<CDR_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['CDR']<CDR_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(CDR100_Target+CDR90_Target+CDR80_Target)
CDR50_Target_df=pd.DataFrame(CDR50_Target).reset_index()
#####################################################################
CDRM10_Target=cc2_After[((cc2_After['CDR']>=CDR_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['CDR']>=CDR_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['CDR']>=CDR_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
CDRM10_Target_df=pd.DataFrame(CDRM10_Target).reset_index()

# %% [markdown]
# # TCH_Cong_Baseline

# %%
TCH_Cong100_BaseLine=cc2_Before[((cc2_Before['TCH_Cong_Rate']<TCH_Cong_H_Th1)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Cong_Rate']<TCH_Cong_E_Th1)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Cong_Rate']<TCH_Cong_N_Th1)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
TCH_Cong100_BaseLine_df=pd.DataFrame(TCH_Cong100_BaseLine).reset_index()
#####################################################################
TCH_Cong90_BaseLine=(cc2_Before[((cc2_Before['TCH_Cong_Rate']<TCH_Cong_H_Th2)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Cong_Rate']<TCH_Cong_E_Th2)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Cong_Rate']<TCH_Cong_N_Th2)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-TCH_Cong100_BaseLine
TCH_Cong90_BaseLine_df=pd.DataFrame(TCH_Cong90_BaseLine).reset_index()
#####################################################################
TCH_Cong80_BaseLine=(cc2_Before[((cc2_Before['TCH_Cong_Rate']<TCH_Cong_H_Th3)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Cong_Rate']<TCH_Cong_E_Th3)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Cong_Rate']<TCH_Cong_N_Th3)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(TCH_Cong100_BaseLine+TCH_Cong90_BaseLine)
TCH_Cong80_BaseLine_df=pd.DataFrame(TCH_Cong80_BaseLine).reset_index()
#####################################################################
TCH_Cong50_BaseLine=(cc2_Before[((cc2_Before['TCH_Cong_Rate']<TCH_Cong_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Cong_Rate']<TCH_Cong_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Cong_Rate']<TCH_Cong_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(TCH_Cong100_BaseLine+TCH_Cong90_BaseLine+TCH_Cong80_BaseLine)
TCH_Cong50_BaseLine_df=pd.DataFrame(TCH_Cong50_BaseLine).reset_index()
#####################################################################
TCH_CongM10_BaseLine=cc2_Before[((cc2_Before['TCH_Cong_Rate']>=TCH_Cong_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Cong_Rate']>=TCH_Cong_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Cong_Rate']>=TCH_Cong_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
TCH_CongM10_BaseLine_df=pd.DataFrame(TCH_CongM10_BaseLine).reset_index()

# %% [markdown]
# # TCH_Cong_Target

# %%
TCH_Cong100_Target=cc2_After[((cc2_After['TCH_Cong_Rate']<TCH_Cong_H_Th1)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Cong_Rate']<TCH_Cong_E_Th1)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Cong_Rate']<TCH_Cong_N_Th1)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
TCH_Cong100_Target_df=pd.DataFrame(TCH_Cong100_Target).reset_index()
#####################################################################
TCH_Cong90_Target=(cc2_After[((cc2_After['TCH_Cong_Rate']<TCH_Cong_H_Th2)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Cong_Rate']<TCH_Cong_E_Th2)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Cong_Rate']<TCH_Cong_N_Th2)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-TCH_Cong100_Target
TCH_Cong90_Target_df=pd.DataFrame(TCH_Cong90_Target).reset_index()
#####################################################################
TCH_Cong80_Target=(cc2_After[((cc2_After['TCH_Cong_Rate']<TCH_Cong_H_Th3)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Cong_Rate']<TCH_Cong_E_Th3)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Cong_Rate']<TCH_Cong_N_Th3)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(TCH_Cong100_Target+TCH_Cong90_Target)
TCH_Cong80_Target_df=pd.DataFrame(TCH_Cong80_Target).reset_index()
#####################################################################
TCH_Cong50_Target=(cc2_After[((cc2_After['TCH_Cong_Rate']<TCH_Cong_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Cong_Rate']<TCH_Cong_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Cong_Rate']<TCH_Cong_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(TCH_Cong100_Target+TCH_Cong90_Target+TCH_Cong80_Target)
TCH_Cong50_Target_df=pd.DataFrame(TCH_Cong50_Target).reset_index()
#####################################################################
TCH_CongM10_Target=cc2_After[((cc2_After['TCH_Cong_Rate']>=TCH_Cong_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Cong_Rate']>=TCH_Cong_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Cong_Rate']>=TCH_Cong_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
TCH_CongM10_Target_df=pd.DataFrame(TCH_CongM10_Target).reset_index()

# %% [markdown]
# # TAFR_Dashboard_Baseline

# %%
TAFR100_BaseLine=cc2_Before[((cc2_Before['TCH_Ass_FR']<TAFR_H_Th1)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Ass_FR']<TAFR_E_Th1)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Ass_FR']<TAFR_N_Th1)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
TAFR100_BaseLine_df=pd.DataFrame(TAFR100_BaseLine).reset_index()
#####################################################################
TAFR90_BaseLine=(cc2_Before[((cc2_Before['TCH_Ass_FR']<TAFR_H_Th2)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Ass_FR']<TAFR_E_Th2)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Ass_FR']<TAFR_N_Th2)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-TAFR100_BaseLine
TAFR90_BaseLine_df=pd.DataFrame(TAFR90_BaseLine).reset_index()
#####################################################################
TAFR80_BaseLine=(cc2_Before[((cc2_Before['TCH_Ass_FR']<TAFR_H_Th3)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Ass_FR']<TAFR_E_Th3)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Ass_FR']<TAFR_N_Th3)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(TAFR100_BaseLine+TAFR90_BaseLine)
TAFR80_BaseLine_df=pd.DataFrame(TAFR80_BaseLine).reset_index()
#####################################################################
TAFR50_BaseLine=(cc2_Before[((cc2_Before['TCH_Ass_FR']<TAFR_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Ass_FR']<TAFR_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Ass_FR']<TAFR_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(TAFR100_BaseLine+TAFR90_BaseLine+TAFR80_BaseLine)
TAFR50_BaseLine_df=pd.DataFrame(TAFR50_BaseLine).reset_index()
#####################################################################
TAFRM10_BaseLine=cc2_Before[((cc2_Before['TCH_Ass_FR']>=TAFR_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['TCH_Ass_FR']>=TAFR_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['TCH_Ass_FR']>=TAFR_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
TAFRM10_BaseLine_df=pd.DataFrame(TAFRM10_BaseLine).reset_index()

# %% [markdown]
# # TAFR_Dashboard_Target

# %%
TAFR100_Target=cc2_After[((cc2_After['TCH_Ass_FR']<TAFR_H_Th1)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Ass_FR']<TAFR_E_Th1)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Ass_FR']<TAFR_N_Th1)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
TAFR100_Target_df=pd.DataFrame(TAFR100_Target).reset_index()
#####################################################################
TAFR90_Target=(cc2_After[((cc2_After['TCH_Ass_FR']<TAFR_H_Th2)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Ass_FR']<TAFR_E_Th2)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Ass_FR']<TAFR_N_Th2)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-TAFR100_Target
TAFR90_Target_df=pd.DataFrame(TAFR90_Target).reset_index()
#####################################################################
TAFR80_Target=(cc2_After[((cc2_After['TCH_Ass_FR']<TAFR_H_Th3)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Ass_FR']<TAFR_E_Th3)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Ass_FR']<TAFR_N_Th3)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(TAFR100_Target+TAFR90_Target)
TAFR80_Target_df=pd.DataFrame(TAFR80_Target).reset_index()
#####################################################################
TAFR50_Target=(cc2_After[((cc2_After['TCH_Ass_FR']<TAFR_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Ass_FR']<TAFR_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Ass_FR']<TAFR_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(TAFR100_Target+TAFR90_Target+TAFR80_Target)
TAFR50_Target_df=pd.DataFrame(TAFR50_Target).reset_index()
#####################################################################
TAFRM10_Target=cc2_After[((cc2_After['TCH_Ass_FR']>=TAFR_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['TCH_Ass_FR']>=TAFR_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['TCH_Ass_FR']>=TAFR_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
TAFRM10_Target_df=pd.DataFrame(TAFRM10_Target).reset_index()

# %% [markdown]
# # SD_Drop_Dashboard_Baseline

# %%
SD_Drop100_BaseLine=cc2_Before[((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_H_Th1)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_E_Th1)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_N_Th1)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
SD_Drop100_BaseLine_df=pd.DataFrame(SD_Drop100_BaseLine).reset_index()
#####################################################################
SD_Drop90_BaseLine=(cc2_Before[((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_H_Th2)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_E_Th2)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_N_Th2)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-SD_Drop100_BaseLine
SD_Drop90_BaseLine_df=pd.DataFrame(SD_Drop90_BaseLine).reset_index()
#####################################################################
SD_Drop80_BaseLine=(cc2_Before[((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_H_Th3)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_E_Th3)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_N_Th3)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(SD_Drop100_BaseLine+SD_Drop90_BaseLine)
SD_Drop80_BaseLine_df=pd.DataFrame(SD_Drop80_BaseLine).reset_index()
#####################################################################
SD_Drop50_BaseLine=(cc2_Before[((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Drop_Rate']<SD_Drop_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(SD_Drop100_BaseLine+SD_Drop90_BaseLine+SD_Drop80_BaseLine)
SD_Drop50_BaseLine_df=pd.DataFrame(SD_Drop50_BaseLine).reset_index()
#####################################################################
SD_DropM10_BaseLine=cc2_Before[((cc2_Before['SDCCH_Drop_Rate']>=SD_Drop_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Drop_Rate']>=SD_Drop_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Drop_Rate']>=SD_Drop_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
SD_DropM10_BaseLine_df=pd.DataFrame(SD_DropM10_BaseLine).reset_index()

# %% [markdown]
# # SD_Drop_Dashboard_Target

# %%
SD_Drop100_Target=cc2_After[((cc2_After['SDCCH_Drop_Rate']<SD_Drop_H_Th1)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Drop_Rate']<SD_Drop_E_Th1)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Drop_Rate']<SD_Drop_N_Th1)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
SD_Drop100_Target_df=pd.DataFrame(SD_Drop100_Target).reset_index()
#####################################################################
SD_Drop90_Target=(cc2_After[((cc2_After['SDCCH_Drop_Rate']<SD_Drop_H_Th2)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Drop_Rate']<SD_Drop_E_Th2)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Drop_Rate']<SD_Drop_N_Th2)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-SD_Drop100_Target
SD_Drop90_Target_df=pd.DataFrame(SD_Drop90_Target).reset_index()
#####################################################################
SD_Drop80_Target=(cc2_After[((cc2_After['SDCCH_Drop_Rate']<SD_Drop_H_Th3)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Drop_Rate']<SD_Drop_E_Th3)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Drop_Rate']<SD_Drop_N_Th3)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(SD_Drop100_Target+SD_Drop90_Target)
SD_Drop80_Target_df=pd.DataFrame(SD_Drop80_Target).reset_index()
#####################################################################
SD_Drop50_Target=(cc2_After[((cc2_After['SDCCH_Drop_Rate']<SD_Drop_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Drop_Rate']<SD_Drop_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Drop_Rate']<SD_Drop_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(SD_Drop100_Target+SD_Drop90_Target+SD_Drop80_Target)
SD_Drop50_Target_df=pd.DataFrame(SD_Drop50_Target).reset_index()
#####################################################################
SD_DropM10_Target=cc2_After[((cc2_After['SDCCH_Drop_Rate']>=SD_Drop_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Drop_Rate']>=SD_Drop_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Drop_Rate']>=SD_Drop_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
SD_DropM10_Target_df=pd.DataFrame(SD_DropM10_Target).reset_index()

# %% [markdown]
# # Rx-Qual_Dashboard_Baseline

# %%
Rx_Qual100_BaseLine=cc2_Before[((cc2_Before['RX-Quality']>Rx_Qual_H_Th1)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['RX-Quality']>Rx_Qual_E_Th1)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['RX-Quality']>Rx_Qual_N_Th1)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
Rx_Qual100_BaseLine_df=pd.DataFrame(Rx_Qual100_BaseLine).reset_index()
#####################################################################
Rx_Qual90_BaseLine=(cc2_Before[((cc2_Before['RX-Quality']>Rx_Qual_H_Th2)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['RX-Quality']>Rx_Qual_E_Th2)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['RX-Quality']>Rx_Qual_N_Th2)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-Rx_Qual100_BaseLine
Rx_Qual90_BaseLine_df=pd.DataFrame(Rx_Qual90_BaseLine).reset_index()
#####################################################################
Rx_Qual80_BaseLine=(cc2_Before[((cc2_Before['RX-Quality']>Rx_Qual_H_Th3)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['RX-Quality']>Rx_Qual_E_Th3)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['RX-Quality']>Rx_Qual_N_Th3)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(Rx_Qual100_BaseLine+Rx_Qual90_BaseLine)
Rx_Qual80_BaseLine_df=pd.DataFrame(Rx_Qual80_BaseLine).reset_index()
#####################################################################
Rx_Qual50_BaseLine=(cc2_Before[((cc2_Before['RX-Quality']>Rx_Qual_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['RX-Quality']>Rx_Qual_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['RX-Quality']>Rx_Qual_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(Rx_Qual100_BaseLine+Rx_Qual90_BaseLine+Rx_Qual80_BaseLine)
Rx_Qual50_BaseLine_df=pd.DataFrame(Rx_Qual50_BaseLine).reset_index()
#####################################################################
Rx_QualM10_BaseLine=cc2_Before[((cc2_Before['RX-Quality']<=Rx_Qual_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['RX-Quality']<=Rx_Qual_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['RX-Quality']<=Rx_Qual_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
Rx_QualM10_BaseLine_df=pd.DataFrame(Rx_QualM10_BaseLine).reset_index()

# %% [markdown]
# # Rx-Qual_Dashboard_Target

# %%
Rx_Qual100_Target=cc2_After[((cc2_After['RX-Quality']>Rx_Qual_H_Th1)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['RX-Quality']>Rx_Qual_E_Th1)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['RX-Quality']>Rx_Qual_N_Th1)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
Rx_Qual100_Target_df=pd.DataFrame(Rx_Qual100_Target).reset_index()
#####################################################################
Rx_Qual90_Target=(cc2_After[((cc2_After['RX-Quality']>Rx_Qual_H_Th2)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['RX-Quality']>Rx_Qual_E_Th2)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['RX-Quality']>Rx_Qual_N_Th2)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-Rx_Qual100_Target
Rx_Qual90_Target_df=pd.DataFrame(Rx_Qual90_Target).reset_index()
#####################################################################
Rx_Qual80_Target=(cc2_After[((cc2_After['RX-Quality']>Rx_Qual_H_Th3)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['RX-Quality']>Rx_Qual_E_Th3)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['RX-Quality']>Rx_Qual_N_Th3)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(Rx_Qual100_Target+Rx_Qual90_Target)
Rx_Qual80_Target_df=pd.DataFrame(Rx_Qual80_Target).reset_index()
#####################################################################
Rx_Qual50_Target=(cc2_After[((cc2_After['RX-Quality']>Rx_Qual_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['RX-Quality']>Rx_Qual_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['RX-Quality']>Rx_Qual_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(Rx_Qual100_Target+Rx_Qual90_Target+Rx_Qual80_Target)
Rx_Qual50_Target_df=pd.DataFrame(Rx_Qual50_Target).reset_index()
#####################################################################
Rx_QualM10_Target=cc2_After[((cc2_After['RX-Quality']<=Rx_Qual_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['RX-Quality']<=Rx_Qual_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['RX-Quality']<=Rx_Qual_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
Rx_QualM10_Target_df=pd.DataFrame(Rx_QualM10_Target).reset_index()

# %% [markdown]
# # HOSR_Dashboard_Baseline

# %%
HOSR100_BaseLine=cc2_Before[((cc2_Before['HOSR']>HOSR_H_Th1)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['HOSR']>HOSR_E_Th1)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['HOSR']>HOSR_N_Th1)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
HOSR100_BaseLine_df=pd.DataFrame(HOSR100_BaseLine).reset_index()
#####################################################################
HOSR90_BaseLine=(cc2_Before[((cc2_Before['HOSR']>HOSR_H_Th2)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['HOSR']>HOSR_E_Th2)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['HOSR']>HOSR_N_Th2)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-HOSR100_BaseLine
HOSR90_BaseLine_df=pd.DataFrame(HOSR90_BaseLine).reset_index()
#####################################################################
HOSR80_BaseLine=(cc2_Before[((cc2_Before['HOSR']>HOSR_H_Th3)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['HOSR']>HOSR_E_Th3)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['HOSR']>HOSR_N_Th3)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(HOSR100_BaseLine+HOSR90_BaseLine)
HOSR80_BaseLine_df=pd.DataFrame(HOSR80_BaseLine).reset_index()
#####################################################################
HOSR50_BaseLine=(cc2_Before[((cc2_Before['HOSR']>HOSR_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['HOSR']>HOSR_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['HOSR']>HOSR_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(HOSR100_BaseLine+HOSR90_BaseLine+HOSR80_BaseLine)
HOSR50_BaseLine_df=pd.DataFrame(HOSR50_BaseLine).reset_index()
#####################################################################
HOSRM10_BaseLine=cc2_Before[((cc2_Before['HOSR']<=HOSR_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['HOSR']<=HOSR_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['HOSR']<=HOSR_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
HOSRM10_BaseLine_df=pd.DataFrame(HOSRM10_BaseLine).reset_index()

# %% [markdown]
# # HOSR_Dashboard_Target

# %%
HOSR100_Target=cc2_After[((cc2_After['HOSR']>HOSR_H_Th1)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['HOSR']>HOSR_E_Th1)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['HOSR']>HOSR_N_Th1)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
HOSR100_Target_df=pd.DataFrame(HOSR100_Target).reset_index()
#####################################################################
HOSR90_Target=(cc2_After[((cc2_After['HOSR']>HOSR_H_Th2)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['HOSR']>HOSR_E_Th2)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['HOSR']>HOSR_N_Th2)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-HOSR100_Target
HOSR90_Target_df=pd.DataFrame(HOSR90_Target).reset_index()
#####################################################################
HOSR80_Target=(cc2_After[((cc2_After['HOSR']>HOSR_H_Th3)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['HOSR']>HOSR_E_Th3)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['HOSR']>HOSR_N_Th3)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(HOSR100_Target+HOSR90_Target)
HOSR80_Target_df=pd.DataFrame(HOSR80_Target).reset_index()
#####################################################################
HOSR50_Target=(cc2_After[((cc2_After['HOSR']>HOSR_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['HOSR']>HOSR_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['HOSR']>HOSR_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(HOSR100_Target+HOSR90_Target+HOSR80_Target)
HOSR50_Target_df=pd.DataFrame(HOSR50_Target).reset_index()
#####################################################################
HOSRM10_Target=cc2_After[((cc2_After['HOSR']<=HOSR_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['HOSR']<=HOSR_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['HOSR']<=HOSR_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
HOSRM10_Target_df=pd.DataFrame(HOSRM10_Target).reset_index()

# %% [markdown]
# # SD_ASS_SR_Dashboard_Baseline

# %%
SD_ASS_SR100_BaseLine=cc2_Before[((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_H_Th1)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_E_Th1)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_N_Th1)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
SD_ASS_SR100_BaseLine_df=pd.DataFrame(SD_ASS_SR100_BaseLine).reset_index()
#####################################################################
SD_ASS_SR90_BaseLine=(cc2_Before[((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_H_Th2)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_E_Th2)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_N_Th2)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-SD_ASS_SR100_BaseLine
SD_ASS_SR90_BaseLine_df=pd.DataFrame(SD_ASS_SR90_BaseLine).reset_index()
#####################################################################
SD_ASS_SR80_BaseLine=(cc2_Before[((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_H_Th3)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_E_Th3)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_N_Th3)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(SD_ASS_SR100_BaseLine+SD_ASS_SR90_BaseLine)
SD_ASS_SR80_BaseLine_df=pd.DataFrame(SD_ASS_SR80_BaseLine).reset_index()
#####################################################################
SD_ASS_SR50_BaseLine=(cc2_Before[((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']>SD_ASS_SR_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count())-(SD_ASS_SR100_BaseLine+SD_ASS_SR90_BaseLine+SD_ASS_SR80_BaseLine)
SD_ASS_SR50_BaseLine_df=pd.DataFrame(SD_ASS_SR50_BaseLine).reset_index()
#####################################################################
SD_ASS_SRM10_BaseLine=cc2_Before[((cc2_Before['SDCCH_Access_Success_Rate']<=SD_ASS_SR_H_Th4)&(cc2_Before['Vendor']=='H'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']<=SD_ASS_SR_E_Th4)&(cc2_Before['Vendor']=='E'))
               | ((cc2_Before['SDCCH_Access_Success_Rate']<=SD_ASS_SR_N_Th4)&(cc2_Before['Vendor']=='N'))].groupby('Index')['CELL'].count()
SD_ASS_SRM10_BaseLine_df=pd.DataFrame(SD_ASS_SRM10_BaseLine).reset_index()

# %% [markdown]
# # SD_ASS_SR_Dashboard_Target

# %%
SD_ASS_SR100_Target=cc2_After[((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_H_Th1)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_E_Th1)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_N_Th1)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
SD_ASS_SR100_Target_df=pd.DataFrame(SD_ASS_SR100_Target).reset_index()
#####################################################################
SD_ASS_SR90_Target=(cc2_After[((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_H_Th2)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_E_Th2)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_N_Th2)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-SD_ASS_SR100_Target
SD_ASS_SR90_Target_df=pd.DataFrame(SD_ASS_SR90_Target).reset_index()
#####################################################################
SD_ASS_SR80_Target=(cc2_After[((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_H_Th3)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_E_Th3)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_N_Th3)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(SD_ASS_SR100_Target+SD_ASS_SR90_Target)
SD_ASS_SR80_Target_df=pd.DataFrame(SD_ASS_SR80_Target).reset_index()
#####################################################################
SD_ASS_SR50_Target=(cc2_After[((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Access_Success_Rate']>SD_ASS_SR_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count())-(SD_ASS_SR100_Target+SD_ASS_SR90_Target+SD_ASS_SR80_Target)
SD_ASS_SR50_Target_df=pd.DataFrame(SD_ASS_SR50_Target).reset_index()
#####################################################################
SD_ASS_SRM10_Target=cc2_After[((cc2_After['SDCCH_Access_Success_Rate']<=SD_ASS_SR_H_Th4)&(cc2_After['Vendor']=='H'))
               | ((cc2_After['SDCCH_Access_Success_Rate']<=SD_ASS_SR_E_Th4)&(cc2_After['Vendor']=='E'))
               | ((cc2_After['SDCCH_Access_Success_Rate']<=SD_ASS_SR_N_Th4)&(cc2_After['Vendor']=='N'))].groupby('Index')['CELL'].count()
SD_ASS_SRM10_Target_df=pd.DataFrame(SD_ASS_SRM10_Target).reset_index()

# %%
Dashboard_Final=Dashboard_Final.merge(CDR100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(CDR90_BaseLine_df,on='Index',suffixes=('CDR100_BaseLine','CDR90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(CDR80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(CDR50_BaseLine_df,on='Index',suffixes=('CDR80_BaseLine','CDR50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(CDRM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLCDRM10_Baseline'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(CDR100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(CDR90_Target_df,on='Index',suffixes=('CDR100_Target','CDR90_Target'))
Dashboard_Final=Dashboard_Final.merge(CDR80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(CDR50_Target_df,on='Index',suffixes=('CDR80_Target','CDR50_Target'))
Dashboard_Final=Dashboard_Final.merge(CDRM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLCDRM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(TCH_Cong100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(TCH_Cong90_BaseLine_df,on='Index',suffixes=('TCH_Cong100_BaseLine','TCH_Cong90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(TCH_Cong80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(TCH_Cong50_BaseLine_df,on='Index',suffixes=('TCH_Cong80_BaseLine','TCH_Cong50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(TCH_CongM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLTCH_CongM10_Baseline'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(TCH_Cong100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(TCH_Cong90_Target_df,on='Index',suffixes=('TCH_Cong100_Target','TCH_Cong90_Target'))
Dashboard_Final=Dashboard_Final.merge(TCH_Cong80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(TCH_Cong50_Target_df,on='Index',suffixes=('TCH_Cong80_Target','TCH_Cong50_Target'))
Dashboard_Final=Dashboard_Final.merge(TCH_CongM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLTCH_CongM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(TAFR100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(TAFR90_BaseLine_df,on='Index',suffixes=('TAFR100_BaseLine','TAFR90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(TAFR80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(TAFR50_BaseLine_df,on='Index',suffixes=('TAFR80_BaseLine','TAFR50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(TAFRM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLTAFRM10_Baseline'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(TAFR100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(TAFR90_Target_df,on='Index',suffixes=('TAFR100_Target','TAFR90_Target'))
Dashboard_Final=Dashboard_Final.merge(TAFR80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(TAFR50_Target_df,on='Index',suffixes=('TAFR80_Target','TAFR50_Target'))
Dashboard_Final=Dashboard_Final.merge(TAFRM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLTAFRM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(SD_Drop100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(SD_Drop90_BaseLine_df,on='Index',suffixes=('SD_Drop100_BaseLine','SD_Drop90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(SD_Drop80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(SD_Drop50_BaseLine_df,on='Index',suffixes=('SD_Drop80_BaseLine','SD_Drop50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(SD_DropM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLSD_DropM10_Baseline'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(SD_Drop100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(SD_Drop90_Target_df,on='Index',suffixes=('SD_Drop100_Target','SD_Drop90_Target'))
Dashboard_Final=Dashboard_Final.merge(SD_Drop80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(SD_Drop50_Target_df,on='Index',suffixes=('SD_Drop80_Target','SD_Drop50_Target'))
Dashboard_Final=Dashboard_Final.merge(SD_DropM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLSD_DropM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(Rx_Qual100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(Rx_Qual90_BaseLine_df,on='Index',suffixes=('Rx_Qual100_BaseLine','Rx_Qual90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(Rx_Qual80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(Rx_Qual50_BaseLine_df,on='Index',suffixes=('Rx_Qual80_BaseLine','Rx_Qual50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(Rx_QualM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLRx_QualM10_Baseline'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(Rx_Qual100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(Rx_Qual90_Target_df,on='Index',suffixes=('Rx_Qual100_Target','Rx_Qual90_Target'))
Dashboard_Final=Dashboard_Final.merge(Rx_Qual80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(Rx_Qual50_Target_df,on='Index',suffixes=('Rx_Qual80_Target','Rx_Qual50_Target'))
Dashboard_Final=Dashboard_Final.merge(Rx_QualM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLRx_QualM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(HOSR100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(HOSR90_BaseLine_df,on='Index',suffixes=('HOSR100_BaseLine','HOSR90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(HOSR80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(HOSR50_BaseLine_df,on='Index',suffixes=('HOSR80_BaseLine','HOSR50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(HOSRM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLHOSRM10_Baseline'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(HOSR100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(HOSR90_Target_df,on='Index',suffixes=('HOSR100_Target','HOSR90_Target'))
Dashboard_Final=Dashboard_Final.merge(HOSR80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(HOSR50_Target_df,on='Index',suffixes=('HOSR80_Target','HOSR50_Target'))
Dashboard_Final=Dashboard_Final.merge(HOSRM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLHOSRM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SR100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SR90_BaseLine_df,on='Index',suffixes=('SD_ASS_SR100_BaseLine','SD_ASS_SR90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SR80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SR50_BaseLine_df,on='Index',suffixes=('SD_ASS_SR80_BaseLine','SD_ASS_SR50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SRM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLSD_ASS_SRM10_Baseline'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SR100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SR90_Target_df,on='Index',suffixes=('SD_ASS_SR100_Target','SD_ASS_SR90_Target'))
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SR80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SR50_Target_df,on='Index',suffixes=('SD_ASS_SR80_Target','SD_ASS_SR50_Target'))
Dashboard_Final=Dashboard_Final.merge(SD_ASS_SRM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'CELL':'CELLSD_ASS_SRM10_Target'},inplace=True)

# %%
# Dashboard_Final.columns
# Out:
# Index(['Index', 'CELL_Baseline', 'SDCCH_Drop_Rate_Baseline',
#        'TCH_Cong_Rate_Baseline', 'SDCCH_Access_Success_Rate_Baseline',
#        'CDR_Baseline', 'RX-Quality_Baseline', 'HOSR_Baseline',
#        'TCH_Ass_FR_Baseline', 'CELL_Target', 'SDCCH_Drop_Rate_Target',
#        'TCH_Cong_Rate_Target', 'SDCCH_Access_Success_Rate_Target',
#        'CDR_Target', 'RX-Quality_Target', 'HOSR_Target', 'TCH_Ass_FR_Target',
#        'CELL_Baseline_Unique', 'CELL_Target_Unique', 'CELLCDR100_BaseLine',
#        'CELLCDR90_BaseLine', 'CELLCDR80_BaseLine', 'CELLCDR50_BaseLine',
#        'CELLCDRM10_Baseline', 'CELLCDR100_Target', 'CELLCDR90_Target',
#        'CELLCDR80_Target', 'CELLCDR50_Target', 'CELLCDRM10_Target',
#        'CELLTCH_Cong100_BaseLine', 'CELLTCH_Cong90_BaseLine',
#        'CELLTCH_Cong80_BaseLine', 'CELLTCH_Cong50_BaseLine',
#        'CELLTCH_CongM10_Baseline', 'CELLTCH_Cong100_Target',
#        'CELLTCH_Cong90_Target', 'CELLTCH_Cong80_Target',
# ...

# %%
Dashboard_Final['CELLCDR100_BaseLine_Percentage']=100*Dashboard_Final['CELLCDR100_BaseLine']/Dashboard_Final['CDR_Baseline']
Dashboard_Final['CELLCDR90_BaseLine_Percentage']=100*Dashboard_Final['CELLCDR90_BaseLine']/Dashboard_Final['CDR_Baseline']
Dashboard_Final['CELLCDR80_BaseLine_Percentage']=100*Dashboard_Final['CELLCDR80_BaseLine']/Dashboard_Final['CDR_Baseline']
Dashboard_Final['CELLCDR50_BaseLine_Percentage']=100*Dashboard_Final['CELLCDR50_BaseLine']/Dashboard_Final['CDR_Baseline']
Dashboard_Final['CELLCDRM10_BaseLine_Percentage']=100*Dashboard_Final['CELLCDRM10_Baseline']/Dashboard_Final['CDR_Baseline']

# %%
Dashboard_Final['CELLCDR100_Target_Percentage']=100*Dashboard_Final['CELLCDR100_Target']/Dashboard_Final['CDR_Target']
Dashboard_Final['CELLCDR90_Target_Percentage']=100*Dashboard_Final['CELLCDR90_Target']/Dashboard_Final['CDR_Target']
Dashboard_Final['CELLCDR80_Target_Percentage']=100*Dashboard_Final['CELLCDR80_Target']/Dashboard_Final['CDR_Target']
Dashboard_Final['CELLCDR50_Target_Percentage']=100*Dashboard_Final['CELLCDR50_Target']/Dashboard_Final['CDR_Target']
Dashboard_Final['CELLCDRM10_Target_Percentage']=100*Dashboard_Final['CELLCDRM10_Target']/Dashboard_Final['CDR_Target']

# %%
Dashboard_Final['CELLTCH_Cong100_BaseLine_Percentage']=100*Dashboard_Final['CELLTCH_Cong100_BaseLine']/Dashboard_Final['TCH_Cong_Rate_Baseline']
Dashboard_Final['CELLTCH_Cong90_BaseLine_Percentage']=100*Dashboard_Final['CELLTCH_Cong90_BaseLine']/Dashboard_Final['TCH_Cong_Rate_Baseline']
Dashboard_Final['CELLTCH_Cong80_BaseLine_Percentage']=100*Dashboard_Final['CELLTCH_Cong80_BaseLine']/Dashboard_Final['TCH_Cong_Rate_Baseline']
Dashboard_Final['CELLTCH_Cong50_BaseLine_Percentage']=100*Dashboard_Final['CELLTCH_Cong50_BaseLine']/Dashboard_Final['TCH_Cong_Rate_Baseline']
Dashboard_Final['CELLTCH_CongM10_BaseLine_Percentage']=100*Dashboard_Final['CELLTCH_CongM10_Baseline']/Dashboard_Final['TCH_Cong_Rate_Baseline']

# %%
Dashboard_Final['CELLTCH_Cong100_Target_Percentage']=100*Dashboard_Final['CELLTCH_Cong100_Target']/Dashboard_Final['TCH_Cong_Rate_Target']
Dashboard_Final['CELLTCH_Cong90_Target_Percentage']=100*Dashboard_Final['CELLTCH_Cong90_Target']/Dashboard_Final['TCH_Cong_Rate_Target']
Dashboard_Final['CELLTCH_Cong80_Target_Percentage']=100*Dashboard_Final['CELLTCH_Cong80_Target']/Dashboard_Final['TCH_Cong_Rate_Target']
Dashboard_Final['CELLTCH_Cong50_Target_Percentage']=100*Dashboard_Final['CELLTCH_Cong50_Target']/Dashboard_Final['TCH_Cong_Rate_Target']
Dashboard_Final['CELLTCH_CongM10_Target_Percentage']=100*Dashboard_Final['CELLTCH_CongM10_Target']/Dashboard_Final['TCH_Cong_Rate_Target']

# %%
Dashboard_Final['CELLTAFR100_BaseLine_Percentage']=100*Dashboard_Final['CELLTAFR100_BaseLine']/Dashboard_Final['TCH_Ass_FR_Baseline']
Dashboard_Final['CELLTAFR90_BaseLine_Percentage']=100*Dashboard_Final['CELLTAFR90_BaseLine']/Dashboard_Final['TCH_Ass_FR_Baseline']
Dashboard_Final['CELLTAFR80_BaseLine_Percentage']=100*Dashboard_Final['CELLTAFR80_BaseLine']/Dashboard_Final['TCH_Ass_FR_Baseline']
Dashboard_Final['CELLTAFR50_BaseLine_Percentage']=100*Dashboard_Final['CELLTAFR50_BaseLine']/Dashboard_Final['TCH_Ass_FR_Baseline']
Dashboard_Final['CELLTAFRM10_BaseLine_Percentage']=100*Dashboard_Final['CELLTAFRM10_Baseline']/Dashboard_Final['TCH_Ass_FR_Baseline']

# %%
Dashboard_Final['CELLTAFR100_Target_Percentage']=100*Dashboard_Final['CELLTAFR100_Target']/Dashboard_Final['TCH_Ass_FR_Target']
Dashboard_Final['CELLTAFR90_Target_Percentage']=100*Dashboard_Final['CELLTAFR90_Target']/Dashboard_Final['TCH_Ass_FR_Target']
Dashboard_Final['CELLTAFR80_Target_Percentage']=100*Dashboard_Final['CELLTAFR80_Target']/Dashboard_Final['TCH_Ass_FR_Target']
Dashboard_Final['CELLTAFR50_Target_Percentage']=100*Dashboard_Final['CELLTAFR50_Target']/Dashboard_Final['TCH_Ass_FR_Target']
Dashboard_Final['CELLTAFRM10_Target_Percentage']=100*Dashboard_Final['CELLTAFRM10_Target']/Dashboard_Final['TCH_Ass_FR_Target']

# %%
Dashboard_Final['CELLSD_Drop100_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_Drop100_BaseLine']/Dashboard_Final['SDCCH_Drop_Rate_Baseline']
Dashboard_Final['CELLSD_Drop90_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_Drop90_BaseLine']/Dashboard_Final['SDCCH_Drop_Rate_Baseline']
Dashboard_Final['CELLSD_Drop80_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_Drop80_BaseLine']/Dashboard_Final['SDCCH_Drop_Rate_Baseline']
Dashboard_Final['CELLSD_Drop50_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_Drop50_BaseLine']/Dashboard_Final['SDCCH_Drop_Rate_Baseline']
Dashboard_Final['CELLSD_DropM10_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_DropM10_Baseline']/Dashboard_Final['SDCCH_Drop_Rate_Baseline']

# %%
Dashboard_Final['CELLSD_Drop100_Target_Percentage']=100*Dashboard_Final['CELLSD_Drop100_Target']/Dashboard_Final['SDCCH_Drop_Rate_Target']
Dashboard_Final['CELLSD_Drop90_Target_Percentage']=100*Dashboard_Final['CELLSD_Drop90_Target']/Dashboard_Final['SDCCH_Drop_Rate_Target']
Dashboard_Final['CELLSD_Drop80_Target_Percentage']=100*Dashboard_Final['CELLSD_Drop80_Target']/Dashboard_Final['SDCCH_Drop_Rate_Target']
Dashboard_Final['CELLSD_Drop50_Target_Percentage']=100*Dashboard_Final['CELLSD_Drop50_Target']/Dashboard_Final['SDCCH_Drop_Rate_Target']
Dashboard_Final['CELLSD_DropM10_Target_Percentage']=100*Dashboard_Final['CELLSD_DropM10_Target']/Dashboard_Final['SDCCH_Drop_Rate_Target']

# %%
Dashboard_Final['CELLRx_Qual100_BaseLine_Percentage']=100*Dashboard_Final['CELLRx_Qual100_BaseLine']/Dashboard_Final['RX-Quality_Baseline']
Dashboard_Final['CELLRx_Qual90_BaseLine_Percentage']=100*Dashboard_Final['CELLRx_Qual90_BaseLine']/Dashboard_Final['RX-Quality_Baseline']
Dashboard_Final['CELLRx_Qual80_BaseLine_Percentage']=100*Dashboard_Final['CELLRx_Qual80_BaseLine']/Dashboard_Final['RX-Quality_Baseline']
Dashboard_Final['CELLRx_Qual50_BaseLine_Percentage']=100*Dashboard_Final['CELLRx_Qual50_BaseLine']/Dashboard_Final['RX-Quality_Baseline']
Dashboard_Final['CELLRx_QualM10_BaseLine_Percentage']=100*Dashboard_Final['CELLRx_QualM10_Baseline']/Dashboard_Final['RX-Quality_Baseline']

# %%
Dashboard_Final['CELLRx_Qual100_Target_Percentage']=100*Dashboard_Final['CELLRx_Qual100_Target']/Dashboard_Final['RX-Quality_Target']
Dashboard_Final['CELLRx_Qual90_Target_Percentage']=100*Dashboard_Final['CELLRx_Qual90_Target']/Dashboard_Final['RX-Quality_Target']
Dashboard_Final['CELLRx_Qual80_Target_Percentage']=100*Dashboard_Final['CELLRx_Qual80_Target']/Dashboard_Final['RX-Quality_Target']
Dashboard_Final['CELLRx_Qual50_Target_Percentage']=100*Dashboard_Final['CELLRx_Qual50_Target']/Dashboard_Final['RX-Quality_Target']
Dashboard_Final['CELLRx_QualM10_Target_Percentage']=100*Dashboard_Final['CELLRx_QualM10_Target']/Dashboard_Final['RX-Quality_Target']

# %%
Dashboard_Final['CELLHOSR100_BaseLine_Percentage']=100*Dashboard_Final['CELLHOSR100_BaseLine']/Dashboard_Final['HOSR_Baseline']
Dashboard_Final['CELLHOSR90_BaseLine_Percentage']=100*Dashboard_Final['CELLHOSR90_BaseLine']/Dashboard_Final['HOSR_Baseline']
Dashboard_Final['CELLHOSR80_BaseLine_Percentage']=100*Dashboard_Final['CELLHOSR80_BaseLine']/Dashboard_Final['HOSR_Baseline']
Dashboard_Final['CELLHOSR50_BaseLine_Percentage']=100*Dashboard_Final['CELLHOSR50_BaseLine']/Dashboard_Final['HOSR_Baseline']
Dashboard_Final['CELLHOSRM10_BaseLine_Percentage']=100*Dashboard_Final['CELLHOSRM10_Baseline']/Dashboard_Final['HOSR_Baseline']

# %%
Dashboard_Final['CELLHOSR100_Target_Percentage']=100*Dashboard_Final['CELLHOSR100_Target']/Dashboard_Final['HOSR_Target']
Dashboard_Final['CELLHOSR90_Target_Percentage']=100*Dashboard_Final['CELLHOSR90_Target']/Dashboard_Final['HOSR_Target']
Dashboard_Final['CELLHOSR80_Target_Percentage']=100*Dashboard_Final['CELLHOSR80_Target']/Dashboard_Final['HOSR_Target']
Dashboard_Final['CELLHOSR50_Target_Percentage']=100*Dashboard_Final['CELLHOSR50_Target']/Dashboard_Final['HOSR_Target']
Dashboard_Final['CELLHOSRM10_Target_Percentage']=100*Dashboard_Final['CELLHOSRM10_Target']/Dashboard_Final['HOSR_Target']

# %%
Dashboard_Final['CELLSD_ASS_SR100_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_ASS_SR100_BaseLine']/Dashboard_Final['SDCCH_Access_Success_Rate_Baseline']
Dashboard_Final['CELLSD_ASS_SR90_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_ASS_SR90_BaseLine']/Dashboard_Final['SDCCH_Access_Success_Rate_Baseline']
Dashboard_Final['CELLSD_ASS_SR80_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_ASS_SR80_BaseLine']/Dashboard_Final['SDCCH_Access_Success_Rate_Baseline']
Dashboard_Final['CELLSD_ASS_SR50_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_ASS_SR50_BaseLine']/Dashboard_Final['SDCCH_Access_Success_Rate_Baseline']
Dashboard_Final['CELLSD_ASS_SRM10_BaseLine_Percentage']=100*Dashboard_Final['CELLSD_ASS_SRM10_Baseline']/Dashboard_Final['SDCCH_Access_Success_Rate_Baseline']

# %%
Dashboard_Final['CELLSD_ASS_SR100_Target_Percentage']=100*Dashboard_Final['CELLSD_ASS_SR100_Target']/Dashboard_Final['SDCCH_Access_Success_Rate_Target']
Dashboard_Final['CELLSD_ASS_SR90_Target_Percentage']=100*Dashboard_Final['CELLSD_ASS_SR90_Target']/Dashboard_Final['SDCCH_Access_Success_Rate_Target']
Dashboard_Final['CELLSD_ASS_SR80_Target_Percentage']=100*Dashboard_Final['CELLSD_ASS_SR80_Target']/Dashboard_Final['SDCCH_Access_Success_Rate_Target']
Dashboard_Final['CELLSD_ASS_SR50_Target_Percentage']=100*Dashboard_Final['CELLSD_ASS_SR50_Target']/Dashboard_Final['SDCCH_Access_Success_Rate_Target']
Dashboard_Final['CELLSD_ASS_SRM10_Target_Percentage']=100*Dashboard_Final['CELLSD_ASS_SRM10_Target']/Dashboard_Final['SDCCH_Access_Success_Rate_Target']

# %% [markdown]
# # Mark

# %%
Dashboard_Final['Mark_CDR_Baseline']=Dashboard_Final['CELLCDR100_BaseLine_Percentage']*1+Dashboard_Final['CELLCDR90_BaseLine_Percentage']*0.9+Dashboard_Final['CELLCDR80_BaseLine_Percentage']*0.8+Dashboard_Final['CELLCDR50_BaseLine_Percentage']*0.5+Dashboard_Final['CELLCDRM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_CDR_Target']=Dashboard_Final['CELLCDR100_Target_Percentage']*1+Dashboard_Final['CELLCDR90_Target_Percentage']*0.9+Dashboard_Final['CELLCDR80_Target_Percentage']*0.8+Dashboard_Final['CELLCDR50_Target_Percentage']*0.5+Dashboard_Final['CELLCDRM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_TCH_Cong_Baseline']=Dashboard_Final['CELLTCH_Cong100_BaseLine_Percentage']*1+Dashboard_Final['CELLTCH_Cong90_BaseLine_Percentage']*0.9+Dashboard_Final['CELLTCH_Cong80_BaseLine_Percentage']*0.8+Dashboard_Final['CELLTCH_Cong50_BaseLine_Percentage']*0.5+Dashboard_Final['CELLTCH_CongM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_TCH_Cong_Target']=Dashboard_Final['CELLTCH_Cong100_Target_Percentage']*1+Dashboard_Final['CELLTCH_Cong90_Target_Percentage']*0.9+Dashboard_Final['CELLTCH_Cong80_Target_Percentage']*0.8+Dashboard_Final['CELLTCH_Cong50_Target_Percentage']*0.5+Dashboard_Final['CELLTCH_CongM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_TAFR_Baseline']=Dashboard_Final['CELLTAFR100_BaseLine_Percentage']*1+Dashboard_Final['CELLTAFR90_BaseLine_Percentage']*0.9+Dashboard_Final['CELLTAFR80_BaseLine_Percentage']*0.8+Dashboard_Final['CELLTAFR50_BaseLine_Percentage']*0.5+Dashboard_Final['CELLTAFRM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_TAFR_Target']=Dashboard_Final['CELLTAFR100_Target_Percentage']*1+Dashboard_Final['CELLTAFR90_Target_Percentage']*0.9+Dashboard_Final['CELLTAFR80_Target_Percentage']*0.8+Dashboard_Final['CELLTAFR50_Target_Percentage']*0.5+Dashboard_Final['CELLTAFRM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_SD_Drop_Baseline']=Dashboard_Final['CELLSD_Drop100_BaseLine_Percentage']*1+Dashboard_Final['CELLSD_Drop90_BaseLine_Percentage']*0.9+Dashboard_Final['CELLSD_Drop80_BaseLine_Percentage']*0.8+Dashboard_Final['CELLSD_Drop50_BaseLine_Percentage']*0.5+Dashboard_Final['CELLSD_DropM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_SD_Drop_Target']=Dashboard_Final['CELLSD_Drop100_Target_Percentage']*1+Dashboard_Final['CELLSD_Drop90_Target_Percentage']*0.9+Dashboard_Final['CELLSD_Drop80_Target_Percentage']*0.8+Dashboard_Final['CELLSD_Drop50_Target_Percentage']*0.5+Dashboard_Final['CELLSD_DropM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_Rx_Qual_Baseline']=Dashboard_Final['CELLRx_Qual100_BaseLine_Percentage']*1+Dashboard_Final['CELLRx_Qual90_BaseLine_Percentage']*0.9+Dashboard_Final['CELLRx_Qual80_BaseLine_Percentage']*0.8+Dashboard_Final['CELLRx_Qual50_BaseLine_Percentage']*0.5+Dashboard_Final['CELLRx_QualM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_Rx_Qual_Target']=Dashboard_Final['CELLRx_Qual100_Target_Percentage']*1+Dashboard_Final['CELLRx_Qual90_Target_Percentage']*0.9+Dashboard_Final['CELLRx_Qual80_Target_Percentage']*0.8+Dashboard_Final['CELLRx_Qual50_Target_Percentage']*0.5+Dashboard_Final['CELLRx_QualM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_HOSR_Baseline']=Dashboard_Final['CELLHOSR100_BaseLine_Percentage']*1+Dashboard_Final['CELLHOSR90_BaseLine_Percentage']*0.9+Dashboard_Final['CELLHOSR80_BaseLine_Percentage']*0.8+Dashboard_Final['CELLHOSR50_BaseLine_Percentage']*0.5+Dashboard_Final['CELLHOSRM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_HOSR_Target']=Dashboard_Final['CELLHOSR100_Target_Percentage']*1+Dashboard_Final['CELLHOSR90_Target_Percentage']*0.9+Dashboard_Final['CELLHOSR80_Target_Percentage']*0.8+Dashboard_Final['CELLHOSR50_Target_Percentage']*0.5+Dashboard_Final['CELLHOSRM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_SD_ASS_SR_Baseline']=Dashboard_Final['CELLSD_ASS_SR100_BaseLine_Percentage']*1+Dashboard_Final['CELLSD_ASS_SR90_BaseLine_Percentage']*0.9+Dashboard_Final['CELLSD_ASS_SR80_BaseLine_Percentage']*0.8+Dashboard_Final['CELLSD_ASS_SR50_BaseLine_Percentage']*0.5+Dashboard_Final['CELLSD_ASS_SRM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_SD_ASS_SR_Target']=Dashboard_Final['CELLSD_ASS_SR100_Target_Percentage']*1+Dashboard_Final['CELLSD_ASS_SR90_Target_Percentage']*0.9+Dashboard_Final['CELLSD_ASS_SR80_Target_Percentage']*0.8+Dashboard_Final['CELLSD_ASS_SR50_Target_Percentage']*0.5+Dashboard_Final['CELLSD_ASS_SRM10_Target_Percentage']*(-0.1)

# %% [markdown]
# # Growth Rate

# %%
Dashboard_Final['CDR_Growth']=100*(Dashboard_Final['Mark_CDR_Target']-Dashboard_Final['Mark_CDR_Baseline'])/Dashboard_Final['Mark_CDR_Baseline']
Dashboard_Final['TAFR_Growth']=100*(Dashboard_Final['Mark_TAFR_Target']-Dashboard_Final['Mark_TAFR_Baseline'])/Dashboard_Final['Mark_TAFR_Baseline']
Dashboard_Final['TCH_Cong_Growth']=100*(Dashboard_Final['Mark_TCH_Cong_Target']-Dashboard_Final['Mark_TCH_Cong_Baseline'])/Dashboard_Final['Mark_TCH_Cong_Baseline']
Dashboard_Final['SD_Drop_Growth']=100*(Dashboard_Final['Mark_SD_Drop_Target']-Dashboard_Final['Mark_SD_Drop_Baseline'])/Dashboard_Final['Mark_SD_Drop_Baseline']
Dashboard_Final['Rx_Qual_Growth']=100*(Dashboard_Final['Mark_Rx_Qual_Target']-Dashboard_Final['Mark_Rx_Qual_Baseline'])/Dashboard_Final['Mark_Rx_Qual_Baseline']
Dashboard_Final['HOSR_Growth']=100*(Dashboard_Final['Mark_HOSR_Target']-Dashboard_Final['Mark_HOSR_Baseline'])/Dashboard_Final['Mark_HOSR_Baseline']
Dashboard_Final['SD_ASS_SR_Growth']=100*(Dashboard_Final['Mark_SD_ASS_SR_Target']-Dashboard_Final['Mark_SD_ASS_SR_Baseline'])/Dashboard_Final['Mark_SD_ASS_SR_Baseline']

# %%
Dashboard_Final.loc[Dashboard_Final['CDR_Growth']<=-10,'CDR_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['CDR_Growth']>=10,'CDR_Growth']=10
Dashboard_Final.loc[Dashboard_Final['TCH_Cong_Growth']<=-10,'TCH_Cong_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['TCH_Cong_Growth']>=10,'TCH_Cong_Growth']=10
Dashboard_Final.loc[Dashboard_Final['TAFR_Growth']<=-10,'TAFR_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['TAFR_Growth']>=10,'TAFR_Growth']=10
Dashboard_Final.loc[Dashboard_Final['SD_Drop_Growth']<=-10,'SD_Drop_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['SD_Drop_Growth']>=10,'SD_Drop_Growth']=10
Dashboard_Final.loc[Dashboard_Final['Rx_Qual_Growth']<=-10,'Rx_Qual_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['Rx_Qual_Growth']>=10,'Rx_Qual_Growth']=10
Dashboard_Final.loc[Dashboard_Final['HOSR_Growth']<=-10,'HOSR_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['HOSR_Growth']>=10,'HOSR_Growth']=10
Dashboard_Final.loc[Dashboard_Final['SD_ASS_SR_Growth']<=-10,'SD_ASS_SR_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['SD_ASS_SR_Growth']>=10,'SD_ASS_SR_Growth']=10

# %% [markdown]
# # Score

# %%
Dashboard_Final['CDR_Score']=(0.9*Dashboard_Final['Mark_CDR_Target']+Dashboard_Final['CDR_Growth'])/100
Dashboard_Final['TCH_Cong_Score']=(0.9*Dashboard_Final['Mark_TCH_Cong_Target']+Dashboard_Final['TCH_Cong_Growth'])/100
Dashboard_Final['TAFR_Score']=(0.9*Dashboard_Final['Mark_TAFR_Target']+Dashboard_Final['TAFR_Growth'])/100
Dashboard_Final['SD_Drop_Score']=(0.9*Dashboard_Final['Mark_SD_Drop_Target']+Dashboard_Final['SD_Drop_Growth'])/100
Dashboard_Final['Rx_Qual_Score']=(0.9*Dashboard_Final['Mark_Rx_Qual_Target']+Dashboard_Final['Rx_Qual_Growth'])/100
Dashboard_Final['HOSR_Score']=(0.9*Dashboard_Final['Mark_HOSR_Target']+Dashboard_Final['HOSR_Growth'])/100
Dashboard_Final['SD_ASS_SR_Score']=(0.9*Dashboard_Final['Mark_SD_ASS_SR_Target']+Dashboard_Final['SD_ASS_SR_Growth'])/100

# %%
Dashboard_Final=Dashboard_Final[Dashboard_Final['Index']!='XH']

# %%
# Dashboard_Final
# Out:
#    Index  CELL_Baseline  SDCCH_Drop_Rate_Baseline  TCH_Cong_Rate_Baseline  \
# 0     AG          25664                     25664                   25664
# 1     AR          20607                     20607                   20607
# 2     AS          38413                     38413                   38413
# 3     BU          18627                     18627                   18627
# 4     CH          15469                     15469                   15469
# 5     ES          57161                     57161                   57161
# 6     FS          46651                     46651                   46651
# 7     GL          30515                     30515                   30515
# 8     GN          18483                     18483                   18483
# 9     HN          19694                     19694                   19694
# 10    HZ          29502                     29502                   29502
# 11    IL           9752                      9752                    9752
# ...

# %%
y=(Dashboard_Final['CDR_Score']-min(Dashboard_Final['CDR_Score']))/(max(Dashboard_Final['CDR_Score'])-min(Dashboard_Final['CDR_Score']))
Dashboard_Final['CDR_Score_NO']=(0.5+0.5*y)

# %%
y1=(Dashboard_Final['TCH_Cong_Score']-min(Dashboard_Final['TCH_Cong_Score']))/(max(Dashboard_Final['TCH_Cong_Score'])-min(Dashboard_Final['TCH_Cong_Score']))
Dashboard_Final['TCH_Cong_Score_NO']=(0.5+0.5*y1)
y2=(Dashboard_Final['TAFR_Score']-min(Dashboard_Final['TAFR_Score']))/(max(Dashboard_Final['TAFR_Score'])-min(Dashboard_Final['TAFR_Score']))
Dashboard_Final['TAFR_Score_NO']=(0.5+0.5*y2)
y3=(Dashboard_Final['SD_Drop_Score']-min(Dashboard_Final['SD_Drop_Score']))/(max(Dashboard_Final['SD_Drop_Score'])-min(Dashboard_Final['SD_Drop_Score']))
Dashboard_Final['SD_Drop_Score_NO']=(0.5+0.5*y3)
y4=(Dashboard_Final['Rx_Qual_Score']-min(Dashboard_Final['Rx_Qual_Score']))/(max(Dashboard_Final['Rx_Qual_Score'])-min(Dashboard_Final['Rx_Qual_Score']))
Dashboard_Final['Rx_Qual_Score_NO']=(0.5+0.5*y4)
y5=(Dashboard_Final['HOSR_Score']-min(Dashboard_Final['HOSR_Score']))/(max(Dashboard_Final['HOSR_Score'])-min(Dashboard_Final['HOSR_Score']))
Dashboard_Final['HOSR_Score_NO']=(0.5+0.5*y5)
y6=(Dashboard_Final['SD_ASS_SR_Score']-min(Dashboard_Final['SD_ASS_SR_Score']))/(max(Dashboard_Final['SD_ASS_SR_Score'])-min(Dashboard_Final['SD_ASS_SR_Score']))
Dashboard_Final['SD_ASS_SR_Score_NO']=(0.5+0.5*y6)

# %%
Dashboard_Final.to_excel('2G_Result_Mehr.xlsx')

# %%
AG = cc2_Before[cc2_Before['Index']=='AG']
AG.to_excel('AG.xlsx')
