# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rd4_Before=pd.read_csv('RD4_BaseLine.csv')

# %%
rd4_Before=rd4_Before[['Datetime','eNodeB','Index','Vendor','MAX_Total_Volume(UL+DL)(GB)',
                       'Cell_Availability(%)','LTE_Service_Success_Rate',
                      'Handover_Execution_Rate','Average_Downlink_User_Throughput(Mbit/s)per 5MHz',
                      'Average_UPlink_User_Throughput(Mbit/s)per 5MHz','DL Cell Spectoral Efficiency (bps/Hz)']]

# %%
rd4_Before
# Out:
#                Datetime      eNodeB Index  Vendor  \
# 0        6/8/2019 12:00  AG1L0002A1    AG  Huawei
# 1        6/9/2019 12:00  AG1L0002A1    AG  Huawei
# 2       6/10/2019 13:00  AG1L0002A1    AG  Huawei
# 3       6/11/2019 19:00  AG1L0002A1    AG  Huawei
# 4       6/12/2019 11:00  AG1L0002A1    AG  Huawei
# 5       6/13/2019 12:00  AG1L0002A1    AG  Huawei
# 6       6/14/2019 12:00  AG1L0002A1    AG  Huawei
# 7       6/15/2019 11:00  AG1L0002A1    AG  Huawei
# 8       6/16/2019 12:00  AG1L0002A1    AG  Huawei
# 9       6/17/2019 12:00  AG1L0002A1    AG  Huawei
# 10      6/18/2019 12:00  AG1L0002A1    AG  Huawei
# 11      6/19/2019 12:00  AG1L0002A1    AG  Huawei
# 12      6/20/2019 12:00  AG1L0002A1    AG  Huawei
# 13      6/21/2019 13:00  AG1L0002A1    AG  Huawei
# 14       6/8/2019 12:00  AG1L0002B1    AG  Huawei
# 15       6/9/2019 12:00  AG1L0002B1    AG  Huawei
# 16      6/10/2019 12:00  AG1L0002B1    AG  Huawei
# 17      6/11/2019 12:00  AG1L0002B1    AG  Huawei
# ...

# %%
rd4_Before=rd4_Before[rd4_Before['Cell_Availability(%)']>90]

# %%
rd4_Before.iloc[:,5:8]=rd4_Before.iloc[:,5:8].apply(lambda x: [100 if (y>100) else y for y in x])
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
rd4_Before[rd4_Before.iloc[:,4:8]<0]=np.nan
rd4_Before[rd4_Before.iloc[:,8:9]<0.1]=np.nan
rd4_Before[rd4_Before.iloc[:,9:10]<0.01]=np.nan
rd4_Before[rd4_Before.iloc[:,10:11]<0.01]=np.nan
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\frame.py:3163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._where(-key, value, inplace=True)
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
rd4_Before.iloc[:,8:9]=rd4_Before.iloc[:,8:9].apply(lambda x: [30 if y>30 else y for y in x])
rd4_Before.iloc[:,9:10]=rd4_Before.iloc[:,9:10].apply(lambda x: [10 if y>10 else y for y in x])
rd4_Before.iloc[:,10:11]=rd4_Before.iloc[:,10:11].apply(lambda x: [4 if y>4 else y for y in x])
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
rd4_Before.describe()
# Out:
#        MAX_Total_Volume(UL+DL)(GB)  Cell_Availability(%)  \
# count                774483.000000         774621.000000
# mean                      3.950758             99.955018
# std                       2.872648              0.426661
# min                       0.000000             90.020000
# 25%                       1.858000            100.000000
# 50%                       3.256000            100.000000
# 75%                       5.317000            100.000000
# max                      40.591000            100.000000
#
#        LTE_Service_Success_Rate  Handover_Execution_Rate  \
# count             774388.000000            770976.000000
# mean                  99.778436                99.275173
# std                    0.852813                 2.401533
# min                    0.000000                 0.000000
# 25%                   99.757000                99.281000
# 50%                   99.899000                99.796000
# ...

# %%
Vendor=rd4_Before[['eNodeB','Vendor']]
Vendor.drop_duplicates(inplace=True)
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
rd4_Before['Day']=rd4_Before['Datetime'].str[:10]
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
rd4_Before.sort_values('MAX_Total_Volume(UL+DL)(GB)', ascending=False,inplace=True)
rd4_Before.drop_duplicates(subset=['eNodeB','Day'],inplace=True)
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
rd4_Before
# Out:
#                Datetime      eNodeB Index    Vendor  \
# 382624   6/14/2019 2:00  KJ2L0749C1    KJ  Ericsson
# 264039   6/12/2019 1:00  HZ2L0239C1    HZ    Huawei
# 264038   6/11/2019 1:00  HZ2L0239C1    HZ    Huawei
# 576680   6/9/2019 10:00  SB2L0052B1    SB     Nokia
# 394778  6/14/2019 12:00  KM2L0042B1    KM     Nokia
# 5428    6/16/2019 18:00  AG1L0647C1    AG    Huawei
# 432069   6/12/2019 1:00  KZ1L0148A1    KZ    Huawei
# 568223  6/12/2019 22:00  SB1L0026A1    SB     Nokia
# 5426    6/14/2019 18:00  AG1L0647C1    AG    Huawei
# 10187   6/13/2019 23:00  AG2L0081B1    AG    Huawei
# 568219   6/8/2019 21:00  SB1L0026A1    SB     Nokia
# 274265   6/21/2019 9:00  IL2L0034A1    IL     Nokia
# 10194   6/20/2019 23:00  AG2L0081B1    AG    Huawei
# 568231  6/20/2019 22:00  SB1L0026A1    SB     Nokia
# 10195    6/21/2019 0:00  AG2L0081B1    AG    Huawei
# 5427    6/15/2019 18:00  AG1L0647C1    AG    Huawei
# 568229  6/18/2019 22:00  SB1L0026A1    SB     Nokia
# ...

# %% [markdown]
# # Invalid UL_User_Thr due to Filtering

# %%
# Date1 = input('Date1=')
# Date2 = input('Date2=')
# rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz'] = np.where((rd4_Before['Day']>=Date1) & (rd4_Before['Day']<=Date2), np.nan, rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz'])
# Out:
# Date1=6/08/2019
# Date2=6/14/2019
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Duplicate check

# %%
d = rd4_Before.pivot_table(index=['eNodeB'],aggfunc='size')
d.sort_values(ascending=False)
# Out:
# eNodeB
# ZN2L0381C1    14
# IL1L0021B1    14
# IL1L0003A1    14
# IL1L0002C1    14
# IL1L0002B1    14
# IL1L0002A1    14
# IL1L0001C1    14
# IL1L0001B1    14
# IL1L0001A1    14
# HZ2L0998B1    14
# HZ2L0998A1    14
# HZ2L0903C1    14
# HZ2L0903B1    14
# HZ2L0903A1    14
# HZ2L0621C1    14
# HZ2L0621B1    14
# HZ2L0621A1    14
# HZ2L0617C1    14
# HZ2L0617B1    14
# HZ2L0617A1    14
# HZ2L0616C1    14
# HZ2L0616B1    14
# HZ2L0616A1    14
# HZ2L0609C1    14
# HZ2L0609B1    14
# IL1L0003B1    14
# IL1L0003C1    14
# IL1L0004A1    14
# IL1L0010B1    14
# IL1L0014C1    14
#               ..
# AG1L0057A1     1
# MA2L0663B1     1
# MA2L0663C1     1
# MA2L0663A1     1
# GL2L0225A1     1
# GL2L0225B1     1
# KH2L2498A1     1
# GL2L0225C1     1
# MA2L0142C1     1
# KH2L2498C1     1
# KJ2L0765A1     1
# GL2L0250C1     1
# GN2L0059C1     1
# KH2L2499A1     1
# GN2L0059B1     1
# GN2L0059A1     1
# GL2L0250B1     1
# KH2L2499B1     1
# KH2L2499C1     1
# KJ2L0765B1     1
# GL2L0250A1     1
# ...

# %% [markdown]
# ## After

# %%
rd4_After=pd.read_csv('RD4_Mehr.csv')

# %%
rd4_After=rd4_After[['Datetime','eNodeB','Index','Vendor','MAX_Total_Volume(UL+DL)(GB)',
                       'Cell_Availability(%)','LTE_Service_Success_Rate',
                      'Handover_Execution_Rate','Average_Downlink_User_Throughput(Mbit/s)per 5MHz',
                      'Average_UPlink_User_Throughput(Mbit/s)per 5MHz','DL Cell Spectoral Efficiency (bps/Hz)']]

# %%
rd4_After
# Out:
#                    Datetime      eNodeB Index  Vendor  \
# 0       2019-09-28 23:00:00  AR2L0006A1    AR  Huawei
# 1       2019-09-28 13:00:00  KZ2L0179A1    KZ  Huawei
# 2       2019-09-28 22:00:00  ES2L1601A1    ES  Huawei
# 3       2019-09-28 10:00:00  HZ2L0406C1    HZ  Huawei
# 4       2019-09-28 11:00:00  KS1L0416C1    KS  Huawei
# 5       2019-09-28 23:00:00  AR2L0800B1    AR  Huawei
# 6       2019-09-28 12:00:00  HZ2L0208A1    HZ  Huawei
# 7       2019-09-28 22:00:00  AG1L0093C1    AG  Huawei
# 8       2019-09-28 22:00:00  KD2L0151C1    KD  Huawei
# 9       2019-09-28 22:00:00  AR2L0009C1    AR  Huawei
# 10      2019-09-28 23:00:00  AG2L0888C1    AG  Huawei
# 11      2019-09-28 19:00:00  ES2L2623A1    ES  Huawei
# 12      2019-09-28 22:00:00  HN2L0059C1    HN  Huawei
# 13      2019-09-28 22:00:00  KZ2L0283A1    KZ  Huawei
# 14      2019-09-28 19:00:00  HZ1L0046A1    HZ  Huawei
# 15      2019-09-28 23:00:00  LN1L0511B1    LN  Huawei
# ...

# %%
rd4_After=rd4_After[rd4_After['Cell_Availability(%)']>90]

# %%
rd4_After.iloc[:,5:8]=rd4_After.iloc[:,5:8].apply(lambda x: [100 if (y>100) else y for y in  x])
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
rd4_After[rd4_After.iloc[:,4:8]<0]=np.nan
rd4_After[rd4_After.iloc[:,8:9]<0.1]=np.nan
rd4_After[rd4_After.iloc[:,9:10]<0.01]=np.nan
rd4_After[rd4_After.iloc[:,10:11]<0.01]=np.nan
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\frame.py:3163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._where(-key, value, inplace=True)
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
rd4_After.iloc[:,8:9]=rd4_After.iloc[:,8:9].apply(lambda x: [30 if y>30 else y for y in x])
rd4_After.iloc[:,9:10]=rd4_After.iloc[:,9:10].apply(lambda x: [10 if y>10 else y for y in x])
rd4_After.iloc[:,10:11]=rd4_After.iloc[:,10:11].apply(lambda x: [4 if y>4 else y for y in x])
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
rd4_After.describe()
# Out:
#        MAX_Total_Volume(UL+DL)(GB)  Cell_Availability(%)  \
# count                804221.000000         804758.000000
# mean                      4.178612             99.952635
# std                       2.951323              0.491917
# min                       0.000000             90.025000
# 25%                       2.010000            100.000000
# 50%                       3.495000            100.000000
# 75%                       5.630000            100.000000
# max                      35.729000            100.000000
#
#        LTE_Service_Success_Rate  Handover_Execution_Rate  \
# count             804180.000000            800768.000000
# mean                  99.793981                99.292131
# std                    0.787710                 2.461697
# min                    0.000000                 0.000000
# 25%                   99.769000                99.342000
# 50%                   99.906000                99.853000
# ...

# %%
Vendor_af=rd4_After[['eNodeB','Vendor']]
Vendor_af.drop_duplicates(inplace=True)
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
rd4_After['Day']=rd4_After['Datetime'].str[:10]
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
rd4_After.sort_values('MAX_Total_Volume(UL+DL)(GB)', ascending=False,inplace=True)
rd4_After.drop_duplicates(subset=['eNodeB','Day'],inplace=True)
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Saeed\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ## Duplicate check

# %%
d = rd4_After.pivot_table(index=['eNodeB'],aggfunc='size')
d.sort_values(ascending=False)
# Out:
# eNodeB
# KM1L0992B1    14
# IL2L0021A1    14
# IL2L0029C1    14
# IL2L0029B1    14
# IL2L0029A1    14
# IL2L0028C1    14
# IL2L0028B1    14
# IL2L0028A1    14
# IL2L0027C1    14
# IL2L0027B1    14
# IL2L0027A1    14
# IL2L0021C1    14
# IL2L0021B1    14
# IL2L0020C1    14
# IL2L0014C1    14
# IL2L0020B1    14
# IL2L0020A1    14
# IL2L0019C1    14
# IL2L0019B1    14
# IL2L0019A1    14
# IL2L0018C1    14
# IL2L0018B1    14
# IL2L0018A1    14
# IL2L0017B1    14
# IL2L0017A1    14
# IL2L0015B1    14
# IL2L0031A1    14
# IL2L0031B1    14
# IL2L0031C1    14
# IL2L0032A1    14
#               ..
# KJ2L0069A1     2
# TH2L0351B1     2
# MA2L0020C1     2
# MA2L0020A1     2
# MA2L0020B1     2
# TH2L0351A1     2
# KJ2L0090B1     1
# KJ2L0090C1     1
# KJ2L0433A1     1
# KJ2L0090A1     1
# KH1L0600C1     1
# GL2L0022A1     1
# KH1L0600A1     1
# KH1L0600B1     1
# GL2L0250C1     1
# GL2L0022B1     1
# GL2L0250A1     1
# GL2L0250B1     1
# KJ2L0433B1     1
# GL2L0334A1     1
# GL2L0334B1     1
# ...

# %% [markdown]
# ## Exclusion_Arbaein

# %%
# Arbaein = pd.read_excel('4G_Arbaein_Cells.xlsx')
# condition = rd4_After['eNodeB'].isin(Arbaein['4G_Arbaeen_Cells']) == True
# rd4_After.drop(rd4_After[condition].index, inplace=True)
# Out:
# C:\Users\Saeed\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %% [markdown]
# ## Averaging

# %%
rd4_Before_Avg=rd4_Before.groupby('eNodeB')[rd4_Before.columns[6:]].mean()

# %%
rd4_Before_Avg.reset_index(inplace=True)

# %%
rd4_Before_Avg['Index']=rd4_Before_Avg['eNodeB'].str[:2]
rd4_Before_Avg=pd.merge(rd4_Before_Avg,Vendor,on='eNodeB')

# %%
rd4_After_Avg=rd4_After.groupby('eNodeB')[rd4_After.columns[6:]].mean()

# %%
rd4_After_Avg.reset_index(inplace=True)

# %%
rd4_After_Avg['Index']=rd4_After_Avg['eNodeB'].str[:2]
rd4_After_Avg=pd.merge(rd4_After_Avg,Vendor_af,on='eNodeB')

# %%
PS_CSSR_H=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Huawei']['LTE_Service_Success_Rate']
PS_CSSR_H=PS_CSSR_H.sort_values(ascending=False).reset_index(drop=True)
PS_CSSR_H=PS_CSSR_H[(PS_CSSR_H>=0)&(PS_CSSR_H<=100)]

#################################################################################################

PS_CSSR_N=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Nokia']['LTE_Service_Success_Rate']
PS_CSSR_N=PS_CSSR_N.sort_values(ascending=False).reset_index(drop=True)
PS_CSSR_N=PS_CSSR_N[(PS_CSSR_N>=0)&(PS_CSSR_N<=100)]

#################################################################################################

PS_CSSR_E=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Ericsson']['LTE_Service_Success_Rate']
PS_CSSR_E=PS_CSSR_E.sort_values(ascending=False).reset_index(drop=True)
PS_CSSR_E=PS_CSSR_E[(PS_CSSR_E>=0)&(PS_CSSR_E<=100)]

# %%
HOSR_H=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Huawei']['Handover_Execution_Rate']
HOSR_H=HOSR_H.sort_values(ascending=False).reset_index(drop=True)
HOSR_H=HOSR_H[(HOSR_H>=0)&(HOSR_H<=100)]

#################################################################################################

HOSR_N=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Nokia']['Handover_Execution_Rate']
HOSR_N=HOSR_N.sort_values(ascending=False).reset_index(drop=True)
HOSR_N=HOSR_N[(HOSR_N>=0)&(HOSR_N<=100)]

#################################################################################################

HOSR_E=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Ericsson']['Handover_Execution_Rate']
HOSR_E=HOSR_E.sort_values(ascending=False).reset_index(drop=True)
HOSR_E=HOSR_E[(HOSR_E>=0)&(HOSR_E<=100)]

# %%
DL_User_Thr_H=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Huawei']['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']
DL_User_Thr_H = DL_User_Thr_H.sort_values(ascending=False).reset_index(drop = True)


##############################################################################

DL_User_Thr_N=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Nokia']['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']
DL_User_Thr_N = DL_User_Thr_N.sort_values(ascending=False).reset_index(drop = True)


##############################################################################

DL_User_Thr_E=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Ericsson']['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']
DL_User_Thr_E = DL_User_Thr_E.sort_values(ascending=False).reset_index(drop = True)

# %%
UL_User_Thr_H=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Huawei']['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']
UL_User_Thr_H = UL_User_Thr_H.sort_values(ascending=False).reset_index(drop = True)


##############################################################################

UL_User_Thr_N=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Nokia']['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']
UL_User_Thr_N = UL_User_Thr_N.sort_values(ascending=False).reset_index(drop = True)


##############################################################################

UL_User_Thr_E=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Ericsson']['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']
UL_User_Thr_E = UL_User_Thr_E.sort_values(ascending=False).reset_index(drop = True)

# %%
DL_Cell_SE_H=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Huawei']['DL Cell Spectoral Efficiency (bps/Hz)']
DL_Cell_SE_H = DL_Cell_SE_H.sort_values(ascending=False).reset_index(drop = True)

##############################################################################

DL_Cell_SE_N=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Nokia']['DL Cell Spectoral Efficiency (bps/Hz)']
DL_Cell_SE_N = DL_Cell_SE_N.sort_values(ascending=False).reset_index(drop = True)

##############################################################################

DL_Cell_SE_E=rd4_Before_Avg[rd4_Before_Avg['Vendor']=='Ericsson']['DL Cell Spectoral Efficiency (bps/Hz)']
DL_Cell_SE_E = DL_Cell_SE_E.sort_values(ascending=False).reset_index(drop = True)

# %%
PS_CSSR_H_Th1=(PS_CSSR_H[np.floor(len(PS_CSSR_H)*0.2)]+PS_CSSR_H[np.floor(len(PS_CSSR_H)*0.2)+1])/2
PS_CSSR_H_Th2=(PS_CSSR_H[np.floor(len(PS_CSSR_H)*0.5)]+PS_CSSR_H[np.floor(len(PS_CSSR_H)*0.5)+1])/2
PS_CSSR_H_Th3=(PS_CSSR_H[np.floor(len(PS_CSSR_H)*0.75)]+PS_CSSR_H[np.floor(len(PS_CSSR_H)*0.75)+1])/2
PS_CSSR_H_Th4=(PS_CSSR_H[np.floor(len(PS_CSSR_H)*0.9)]+PS_CSSR_H[np.floor(len(PS_CSSR_H)*0.9)+1])/2
#####################################################################################
PS_CSSR_N_Th1=(PS_CSSR_N[np.floor(len(PS_CSSR_N)*0.2)]+PS_CSSR_N[np.floor(len(PS_CSSR_N)*0.2)+1])/2
PS_CSSR_N_Th2=(PS_CSSR_N[np.floor(len(PS_CSSR_N)*0.5)]+PS_CSSR_N[np.floor(len(PS_CSSR_N)*0.5)+1])/2
PS_CSSR_N_Th3=(PS_CSSR_N[np.floor(len(PS_CSSR_N)*0.75)]+PS_CSSR_N[np.floor(len(PS_CSSR_N)*0.75)+1])/2
PS_CSSR_N_Th4=(PS_CSSR_N[np.floor(len(PS_CSSR_N)*0.9)]+PS_CSSR_N[np.floor(len(PS_CSSR_N)*0.9)+1])/2
#####################################################################################
PS_CSSR_E_Th1=(PS_CSSR_E[np.floor(len(PS_CSSR_E)*0.2)]+PS_CSSR_E[np.floor(len(PS_CSSR_E)*0.2)+1])/2
PS_CSSR_E_Th2=(PS_CSSR_E[np.floor(len(PS_CSSR_E)*0.5)]+PS_CSSR_E[np.floor(len(PS_CSSR_E)*0.5)+1])/2
PS_CSSR_E_Th3=(PS_CSSR_E[np.floor(len(PS_CSSR_E)*0.75)]+PS_CSSR_E[np.floor(len(PS_CSSR_E)*0.75)+1])/2
PS_CSSR_E_Th4=(PS_CSSR_E[np.floor(len(PS_CSSR_E)*0.9)]+PS_CSSR_E[np.floor(len(PS_CSSR_E)*0.9)+1])/2

# %%
HOSR_H_Th1=(HOSR_H[np.floor(len(HOSR_H)*0.2)]+HOSR_H[np.floor(len(HOSR_H)*0.2)+1])/2
HOSR_H_Th2=(HOSR_H[np.floor(len(HOSR_H)*0.5)]+HOSR_H[np.floor(len(HOSR_H)*0.5)+1])/2
HOSR_H_Th3=(HOSR_H[np.floor(len(HOSR_H)*0.75)]+HOSR_H[np.floor(len(HOSR_H)*0.75)+1])/2
HOSR_H_Th4=(HOSR_H[np.floor(len(HOSR_H)*0.9)]+HOSR_H[np.floor(len(HOSR_H)*0.9)+1])/2
#####################################################################################
HOSR_N_Th1=(HOSR_N[np.floor(len(HOSR_N)*0.2)]+HOSR_N[np.floor(len(HOSR_N)*0.2)+1])/2
HOSR_N_Th2=(HOSR_N[np.floor(len(HOSR_N)*0.5)]+HOSR_N[np.floor(len(HOSR_N)*0.5)+1])/2
HOSR_N_Th3=(HOSR_N[np.floor(len(HOSR_N)*0.75)]+HOSR_N[np.floor(len(HOSR_N)*0.75)+1])/2
HOSR_N_Th4=(HOSR_N[np.floor(len(HOSR_N)*0.9)]+HOSR_N[np.floor(len(HOSR_N)*0.9)+1])/2
#####################################################################################
HOSR_E_Th1=(HOSR_E[np.floor(len(HOSR_E)*0.2)]+HOSR_E[np.floor(len(HOSR_E)*0.2)+1])/2
HOSR_E_Th2=(HOSR_E[np.floor(len(HOSR_E)*0.5)]+HOSR_E[np.floor(len(HOSR_E)*0.5)+1])/2
HOSR_E_Th3=(HOSR_E[np.floor(len(HOSR_E)*0.75)]+HOSR_E[np.floor(len(HOSR_E)*0.75)+1])/2
HOSR_E_Th4=(HOSR_E[np.floor(len(HOSR_E)*0.9)]+HOSR_E[np.floor(len(HOSR_E)*0.9)+1])/2

# %%
DL_User_Thr_H_Th1=(DL_User_Thr_H[np.floor(len(DL_User_Thr_H)*0.2)]+DL_User_Thr_H[np.floor(len(DL_User_Thr_H)*0.2)+1])/2
DL_User_Thr_H_Th2=(DL_User_Thr_H[np.floor(len(DL_User_Thr_H)*0.5)]+DL_User_Thr_H[np.floor(len(DL_User_Thr_H)*0.5)+1])/2
DL_User_Thr_H_Th3=(DL_User_Thr_H[np.floor(len(DL_User_Thr_H)*0.75)]+DL_User_Thr_H[np.floor(len(DL_User_Thr_H)*0.75)+1])/2
DL_User_Thr_H_Th4=(DL_User_Thr_H[np.floor(len(DL_User_Thr_H)*0.9)]+DL_User_Thr_H[np.floor(len(DL_User_Thr_H)*0.9)+1])/2
#####################################################################################
DL_User_Thr_N_Th1=(DL_User_Thr_N[np.floor(len(DL_User_Thr_N)*0.2)]+DL_User_Thr_N[np.floor(len(DL_User_Thr_N)*0.2)+1])/2
DL_User_Thr_N_Th2=(DL_User_Thr_N[np.floor(len(DL_User_Thr_N)*0.5)]+DL_User_Thr_N[np.floor(len(DL_User_Thr_N)*0.5)+1])/2
DL_User_Thr_N_Th3=(DL_User_Thr_N[np.floor(len(DL_User_Thr_N)*0.75)]+DL_User_Thr_N[np.floor(len(DL_User_Thr_N)*0.75)+1])/2
DL_User_Thr_N_Th4=(DL_User_Thr_N[np.floor(len(DL_User_Thr_N)*0.9)]+DL_User_Thr_N[np.floor(len(DL_User_Thr_N)*0.9)+1])/2
#####################################################################################
DL_User_Thr_E_Th1=(DL_User_Thr_E[np.floor(len(DL_User_Thr_E)*0.2)]+DL_User_Thr_E[np.floor(len(DL_User_Thr_E)*0.2)+1])/2
DL_User_Thr_E_Th2=(DL_User_Thr_E[np.floor(len(DL_User_Thr_E)*0.5)]+DL_User_Thr_E[np.floor(len(DL_User_Thr_E)*0.5)+1])/2
DL_User_Thr_E_Th3=(DL_User_Thr_E[np.floor(len(DL_User_Thr_E)*0.75)]+DL_User_Thr_E[np.floor(len(DL_User_Thr_E)*0.75)+1])/2
DL_User_Thr_E_Th4=(DL_User_Thr_E[np.floor(len(DL_User_Thr_E)*0.9)]+DL_User_Thr_E[np.floor(len(DL_User_Thr_E)*0.9)+1])/2

# %%
UL_User_Thr_H_Th1=(UL_User_Thr_H[np.floor(len(UL_User_Thr_H)*0.2)]+UL_User_Thr_H[np.floor(len(UL_User_Thr_H)*0.2)+1])/2
UL_User_Thr_H_Th2=(UL_User_Thr_H[np.floor(len(UL_User_Thr_H)*0.5)]+UL_User_Thr_H[np.floor(len(UL_User_Thr_H)*0.5)+1])/2
UL_User_Thr_H_Th3=(UL_User_Thr_H[np.floor(len(UL_User_Thr_H)*0.75)]+UL_User_Thr_H[np.floor(len(UL_User_Thr_H)*0.75)+1])/2
UL_User_Thr_H_Th4=(UL_User_Thr_H[np.floor(len(UL_User_Thr_H)*0.9)]+UL_User_Thr_H[np.floor(len(UL_User_Thr_H)*0.9)+1])/2
#####################################################################################
UL_User_Thr_N_Th1=(UL_User_Thr_N[np.floor(len(UL_User_Thr_N)*0.2)]+UL_User_Thr_N[np.floor(len(UL_User_Thr_N)*0.2)+1])/2
UL_User_Thr_N_Th2=(UL_User_Thr_N[np.floor(len(UL_User_Thr_N)*0.5)]+UL_User_Thr_N[np.floor(len(UL_User_Thr_N)*0.5)+1])/2
UL_User_Thr_N_Th3=(UL_User_Thr_N[np.floor(len(UL_User_Thr_N)*0.75)]+UL_User_Thr_N[np.floor(len(UL_User_Thr_N)*0.75)+1])/2
UL_User_Thr_N_Th4=(UL_User_Thr_N[np.floor(len(UL_User_Thr_N)*0.9)]+UL_User_Thr_N[np.floor(len(UL_User_Thr_N)*0.9)+1])/2
#####################################################################################
UL_User_Thr_E_Th1=(UL_User_Thr_E[np.floor(len(UL_User_Thr_E)*0.2)]+UL_User_Thr_E[np.floor(len(UL_User_Thr_E)*0.2)+1])/2
UL_User_Thr_E_Th2=(UL_User_Thr_E[np.floor(len(UL_User_Thr_E)*0.5)]+UL_User_Thr_E[np.floor(len(UL_User_Thr_E)*0.5)+1])/2
UL_User_Thr_E_Th3=(UL_User_Thr_E[np.floor(len(UL_User_Thr_E)*0.75)]+UL_User_Thr_E[np.floor(len(UL_User_Thr_E)*0.75)+1])/2
UL_User_Thr_E_Th4=(UL_User_Thr_E[np.floor(len(UL_User_Thr_E)*0.9)]+UL_User_Thr_E[np.floor(len(UL_User_Thr_E)*0.9)+1])/2

# %%
DL_Cell_SE_H_Th1=(DL_Cell_SE_H[np.floor(len(DL_Cell_SE_H)*0.2)]+DL_Cell_SE_H[np.floor(len(DL_Cell_SE_H)*0.2)+1])/2
DL_Cell_SE_H_Th2=(DL_Cell_SE_H[np.floor(len(DL_Cell_SE_H)*0.5)]+DL_Cell_SE_H[np.floor(len(DL_Cell_SE_H)*0.5)+1])/2
DL_Cell_SE_H_Th3=(DL_Cell_SE_H[np.floor(len(DL_Cell_SE_H)*0.75)]+DL_Cell_SE_H[np.floor(len(DL_Cell_SE_H)*0.75)+1])/2
DL_Cell_SE_H_Th4=(DL_Cell_SE_H[np.floor(len(DL_Cell_SE_H)*0.9)]+DL_Cell_SE_H[np.floor(len(DL_Cell_SE_H)*0.9)+1])/2
#####################################################################################
DL_Cell_SE_N_Th1=(DL_Cell_SE_N[np.floor(len(DL_Cell_SE_N)*0.2)]+DL_Cell_SE_N[np.floor(len(DL_Cell_SE_N)*0.2)+1])/2
DL_Cell_SE_N_Th2=(DL_Cell_SE_N[np.floor(len(DL_Cell_SE_N)*0.5)]+DL_Cell_SE_N[np.floor(len(DL_Cell_SE_N)*0.5)+1])/2
DL_Cell_SE_N_Th3=(DL_Cell_SE_N[np.floor(len(DL_Cell_SE_N)*0.75)]+DL_Cell_SE_N[np.floor(len(DL_Cell_SE_N)*0.75)+1])/2
DL_Cell_SE_N_Th4=(DL_Cell_SE_N[np.floor(len(DL_Cell_SE_N)*0.9)]+DL_Cell_SE_N[np.floor(len(DL_Cell_SE_N)*0.9)+1])/2
#####################################################################################
DL_Cell_SE_E_Th1=(DL_Cell_SE_E[np.floor(len(DL_Cell_SE_E)*0.2)]+DL_Cell_SE_E[np.floor(len(DL_Cell_SE_E)*0.2)+1])/2
DL_Cell_SE_E_Th2=(DL_Cell_SE_E[np.floor(len(DL_Cell_SE_E)*0.5)]+DL_Cell_SE_E[np.floor(len(DL_Cell_SE_E)*0.5)+1])/2
DL_Cell_SE_E_Th3=(DL_Cell_SE_E[np.floor(len(DL_Cell_SE_E)*0.75)]+DL_Cell_SE_E[np.floor(len(DL_Cell_SE_E)*0.75)+1])/2
DL_Cell_SE_E_Th4=(DL_Cell_SE_E[np.floor(len(DL_Cell_SE_E)*0.9)]+DL_Cell_SE_E[np.floor(len(DL_Cell_SE_E)*0.9)+1])/2

# %% [markdown]
# ## Thresholds to DF

# %%
d = {'Threshold': ['H_TH1','H_TH2','H_TH3','H_TH4','N_TH1','N_TH2','N_TH3','N_TH4','E_TH1','E_TH2','E_TH3','E_TH4'],
     'PS_CSSR': [PS_CSSR_H_Th1, PS_CSSR_H_Th2, PS_CSSR_H_Th3, PS_CSSR_H_Th4, PS_CSSR_N_Th1, PS_CSSR_N_Th2, PS_CSSR_N_Th3, PS_CSSR_N_Th4, PS_CSSR_E_Th1, PS_CSSR_E_Th2, PS_CSSR_E_Th3, PS_CSSR_E_Th4],
     'HOSR': [HOSR_H_Th1, HOSR_H_Th2, HOSR_H_Th3, HOSR_H_Th4, HOSR_N_Th1, HOSR_N_Th2, HOSR_N_Th3, HOSR_N_Th4, HOSR_E_Th1, HOSR_E_Th2, HOSR_E_Th3, HOSR_E_Th4],
     'DL_User_Thr': [DL_User_Thr_H_Th1, DL_User_Thr_H_Th2, DL_User_Thr_H_Th3, DL_User_Thr_H_Th4, DL_User_Thr_N_Th1, DL_User_Thr_N_Th2, DL_User_Thr_N_Th3, DL_User_Thr_N_Th4, DL_User_Thr_E_Th1, DL_User_Thr_E_Th2, DL_User_Thr_E_Th3, DL_User_Thr_E_Th4],
     'UL_User_Thr': [UL_User_Thr_H_Th1, UL_User_Thr_H_Th2, UL_User_Thr_H_Th3, UL_User_Thr_H_Th4, UL_User_Thr_N_Th1, UL_User_Thr_N_Th2, UL_User_Thr_N_Th3, UL_User_Thr_N_Th4, UL_User_Thr_E_Th1, UL_User_Thr_E_Th2, UL_User_Thr_E_Th3, UL_User_Thr_E_Th4],
     'DL_Cell_SE': [DL_Cell_SE_H_Th1, DL_Cell_SE_H_Th2, DL_Cell_SE_H_Th3, DL_Cell_SE_H_Th4, DL_Cell_SE_N_Th1, DL_Cell_SE_N_Th2, DL_Cell_SE_N_Th3, DL_Cell_SE_N_Th4, DL_Cell_SE_E_Th1, DL_Cell_SE_E_Th2, DL_Cell_SE_E_Th3, DL_Cell_SE_E_Th4]
     }
Thresholds = pd.DataFrame(data=d)
Thresholds.to_excel('Thresholds.xlsx')

# %%
a=[]
a=rd4_Before.groupby('Index',as_index=False).count()
a.drop(columns=['Datetime','Vendor','MAX_Total_Volume(UL+DL)(GB)','Cell_Availability(%)','Day'],inplace=True)

# %%
b=[]
b=rd4_After.groupby('Index',as_index=False).count()
b.drop(columns=['Datetime','Vendor','MAX_Total_Volume(UL+DL)(GB)','Cell_Availability(%)','Day'],inplace=True)

# %%
Dashboard_Final=[]
Dashboard_Final=a.merge(b,how='left',on='Index',suffixes=('_Baseline','_Target'))

# %% [markdown]
# ## Unique Cell Count

# %%
Dashboard_Final=Dashboard_Final.merge(rd4_Before_Avg.groupby(by=['Index'],as_index=False)['eNodeB'].count(),on='Index')
Dashboard_Final=Dashboard_Final.merge(rd4_After_Avg.groupby(by=['Index'],as_index=False)['eNodeB'].count(),on='Index')
Dashboard_Final.rename(columns={'eNodeB_x':'eNodeB_Baseline_Unique','eNodeB_y':'eNodeB_Target_Unique'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final[Dashboard_Final['Index']!='WF']
Dashboard_Final=Dashboard_Final[Dashboard_Final['Index']!='TE']

# %%
Dashboard_Final.reset_index(inplace=True,drop=True)

# %%
PS_CSSR100_BaseLine=rd4_Before[((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_H_Th1)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_E_Th1)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_N_Th1)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
PS_CSSR100_BaseLine_df=pd.DataFrame(PS_CSSR100_BaseLine).reset_index()
#####################################################################
PS_CSSR90_BaseLine=(rd4_Before[((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_H_Th2)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_E_Th2)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_N_Th2)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-PS_CSSR100_BaseLine
PS_CSSR90_BaseLine_df=pd.DataFrame(PS_CSSR90_BaseLine).reset_index()
#####################################################################
PS_CSSR80_BaseLine=(rd4_Before[((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_H_Th3)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_E_Th3)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_N_Th3)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(PS_CSSR100_BaseLine+PS_CSSR90_BaseLine)
PS_CSSR80_BaseLine_df=pd.DataFrame(PS_CSSR80_BaseLine).reset_index()
#####################################################################
PS_CSSR50_BaseLine=(rd4_Before[((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['LTE_Service_Success_Rate']>PS_CSSR_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(PS_CSSR100_BaseLine+PS_CSSR90_BaseLine+PS_CSSR80_BaseLine)
PS_CSSR50_BaseLine_df=pd.DataFrame(PS_CSSR50_BaseLine).reset_index()
#####################################################################
PS_CSSRM10_BaseLine=rd4_Before[((rd4_Before['LTE_Service_Success_Rate']<=PS_CSSR_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['LTE_Service_Success_Rate']<=PS_CSSR_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['LTE_Service_Success_Rate']<=PS_CSSR_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
PS_CSSRM10_BaseLine_df=pd.DataFrame(PS_CSSRM10_BaseLine).reset_index()

# %%
PS_CSSR100_Target=rd4_After[((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_H_Th1)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_E_Th1)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_N_Th1)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
PS_CSSR100_Target_df=pd.DataFrame(PS_CSSR100_Target).reset_index()
#####################################################################
PS_CSSR90_Target=(rd4_After[((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_H_Th2)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_E_Th2)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_N_Th2)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-PS_CSSR100_Target
PS_CSSR90_Target_df=pd.DataFrame(PS_CSSR90_Target).reset_index()
#####################################################################
PS_CSSR80_Target=(rd4_After[((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_H_Th3)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_E_Th3)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_N_Th3)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(PS_CSSR100_Target+PS_CSSR90_Target)
PS_CSSR80_Target_df=pd.DataFrame(PS_CSSR80_Target).reset_index()
#####################################################################
PS_CSSR50_Target=(rd4_After[((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['LTE_Service_Success_Rate']>PS_CSSR_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(PS_CSSR100_Target+PS_CSSR90_Target+PS_CSSR80_Target)
PS_CSSR50_Target_df=pd.DataFrame(PS_CSSR50_Target).reset_index()
#####################################################################
PS_CSSRM10_Target=rd4_After[((rd4_After['LTE_Service_Success_Rate']<=PS_CSSR_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['LTE_Service_Success_Rate']<=PS_CSSR_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['LTE_Service_Success_Rate']<=PS_CSSR_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
PS_CSSRM10_Target_df=pd.DataFrame(PS_CSSRM10_Target).reset_index()

# %%
HOSR100_BaseLine=rd4_Before[((rd4_Before['Handover_Execution_Rate']>HOSR_H_Th1)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Handover_Execution_Rate']>HOSR_E_Th1)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Handover_Execution_Rate']>HOSR_N_Th1)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
HOSR100_BaseLine_df=pd.DataFrame(HOSR100_BaseLine).reset_index()
#####################################################################
HOSR90_BaseLine=(rd4_Before[((rd4_Before['Handover_Execution_Rate']>HOSR_H_Th2)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Handover_Execution_Rate']>HOSR_E_Th2)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Handover_Execution_Rate']>HOSR_N_Th2)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-HOSR100_BaseLine
HOSR90_BaseLine_df=pd.DataFrame(HOSR90_BaseLine).reset_index()
#####################################################################
HOSR80_BaseLine=(rd4_Before[((rd4_Before['Handover_Execution_Rate']>HOSR_H_Th3)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Handover_Execution_Rate']>HOSR_E_Th3)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Handover_Execution_Rate']>HOSR_N_Th3)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(HOSR100_BaseLine+HOSR90_BaseLine)
HOSR80_BaseLine_df=pd.DataFrame(HOSR80_BaseLine).reset_index()
#####################################################################
HOSR50_BaseLine=(rd4_Before[((rd4_Before['Handover_Execution_Rate']>HOSR_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Handover_Execution_Rate']>HOSR_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Handover_Execution_Rate']>HOSR_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(HOSR100_BaseLine+HOSR90_BaseLine+HOSR80_BaseLine)
HOSR50_BaseLine_df=pd.DataFrame(HOSR50_BaseLine).reset_index()
#####################################################################
HOSRM10_BaseLine=rd4_Before[((rd4_Before['Handover_Execution_Rate']<=HOSR_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Handover_Execution_Rate']<=HOSR_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Handover_Execution_Rate']<=HOSR_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
HOSRM10_BaseLine_df=pd.DataFrame(HOSRM10_BaseLine).reset_index()

# %%
HOSR100_Target=rd4_After[((rd4_After['Handover_Execution_Rate']>HOSR_H_Th1)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Handover_Execution_Rate']>HOSR_E_Th1)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Handover_Execution_Rate']>HOSR_N_Th1)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
HOSR100_Target_df=pd.DataFrame(HOSR100_Target).reset_index()
#####################################################################
HOSR90_Target=(rd4_After[((rd4_After['Handover_Execution_Rate']>HOSR_H_Th2)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Handover_Execution_Rate']>HOSR_E_Th2)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Handover_Execution_Rate']>HOSR_N_Th2)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-HOSR100_Target
HOSR90_Target_df=pd.DataFrame(HOSR90_Target).reset_index()
#####################################################################
HOSR80_Target=(rd4_After[((rd4_After['Handover_Execution_Rate']>HOSR_H_Th3)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Handover_Execution_Rate']>HOSR_E_Th3)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Handover_Execution_Rate']>HOSR_N_Th3)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(HOSR100_Target+HOSR90_Target)
HOSR80_Target_df=pd.DataFrame(HOSR80_Target).reset_index()
#####################################################################
HOSR50_Target=(rd4_After[((rd4_After['Handover_Execution_Rate']>HOSR_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Handover_Execution_Rate']>HOSR_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Handover_Execution_Rate']>HOSR_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(HOSR100_Target+HOSR90_Target+HOSR80_Target)
HOSR50_Target_df=pd.DataFrame(HOSR50_Target).reset_index()
#####################################################################
HOSRM10_Target=rd4_After[((rd4_After['Handover_Execution_Rate']<=HOSR_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Handover_Execution_Rate']<=HOSR_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Handover_Execution_Rate']<=HOSR_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
HOSRM10_Target_df=pd.DataFrame(HOSRM10_Target).reset_index()

# %%
DL_User_Thr100_BaseLine=rd4_Before[((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_H_Th1)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_E_Th1)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_N_Th1)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
DL_User_Thr100_BaseLine_df=pd.DataFrame(DL_User_Thr100_BaseLine).reset_index()
#####################################################################
DL_User_Thr90_BaseLine=(rd4_Before[((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_H_Th2)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_E_Th2)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_N_Th2)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-DL_User_Thr100_BaseLine
DL_User_Thr90_BaseLine_df=pd.DataFrame(DL_User_Thr90_BaseLine).reset_index()
#####################################################################
DL_User_Thr80_BaseLine=(rd4_Before[((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_H_Th3)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_E_Th3)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_N_Th3)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(DL_User_Thr100_BaseLine+DL_User_Thr90_BaseLine)
DL_User_Thr80_BaseLine_df=pd.DataFrame(DL_User_Thr80_BaseLine).reset_index()
#####################################################################
DL_User_Thr50_BaseLine=(rd4_Before[((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(DL_User_Thr100_BaseLine+DL_User_Thr90_BaseLine+DL_User_Thr80_BaseLine)
DL_User_Thr50_BaseLine_df=pd.DataFrame(DL_User_Thr50_BaseLine).reset_index()
#####################################################################
DL_User_ThrM10_BaseLine=rd4_Before[((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']<=DL_User_Thr_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']<=DL_User_Thr_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']<=DL_User_Thr_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
DL_User_ThrM10_BaseLine_df=pd.DataFrame(DL_User_ThrM10_BaseLine).reset_index()

# %%
DL_User_Thr100_Target=rd4_After[((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_H_Th1)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_E_Th1)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_N_Th1)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
DL_User_Thr100_Target_df=pd.DataFrame(DL_User_Thr100_Target).reset_index()
#####################################################################
DL_User_Thr90_Target=(rd4_After[((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_H_Th2)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_E_Th2)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_N_Th2)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-DL_User_Thr100_Target
DL_User_Thr90_Target_df=pd.DataFrame(DL_User_Thr90_Target).reset_index()
#####################################################################
DL_User_Thr80_Target=(rd4_After[((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_H_Th3)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_E_Th3)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_N_Th3)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(DL_User_Thr100_Target+DL_User_Thr90_Target)
DL_User_Thr80_Target_df=pd.DataFrame(DL_User_Thr80_Target).reset_index()
#####################################################################
DL_User_Thr50_Target=(rd4_After[((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']>DL_User_Thr_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(DL_User_Thr100_Target+DL_User_Thr90_Target+DL_User_Thr80_Target)
DL_User_Thr50_Target_df=pd.DataFrame(DL_User_Thr50_Target).reset_index()
#####################################################################
DL_User_ThrM10_Target=rd4_After[((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']<=DL_User_Thr_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']<=DL_User_Thr_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_Downlink_User_Throughput(Mbit/s)per 5MHz']<=DL_User_Thr_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
DL_User_ThrM10_Target_df=pd.DataFrame(DL_User_ThrM10_Target).reset_index()

# %%
UL_User_Thr100_BaseLine=rd4_Before[((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_H_Th1)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_E_Th1)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_N_Th1)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
UL_User_Thr100_BaseLine_df=pd.DataFrame(UL_User_Thr100_BaseLine).reset_index()
#####################################################################
UL_User_Thr90_BaseLine=(rd4_Before[((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_H_Th2)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_E_Th2)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_N_Th2)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-UL_User_Thr100_BaseLine
UL_User_Thr90_BaseLine_df=pd.DataFrame(UL_User_Thr90_BaseLine).reset_index()
#####################################################################
UL_User_Thr80_BaseLine=(rd4_Before[((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_H_Th3)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_E_Th3)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_N_Th3)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(UL_User_Thr100_BaseLine+UL_User_Thr90_BaseLine)
UL_User_Thr80_BaseLine_df=pd.DataFrame(UL_User_Thr80_BaseLine).reset_index()
#####################################################################
UL_User_Thr50_BaseLine=(rd4_Before[((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(UL_User_Thr100_BaseLine+UL_User_Thr90_BaseLine+UL_User_Thr80_BaseLine)
UL_User_Thr50_BaseLine_df=pd.DataFrame(UL_User_Thr50_BaseLine).reset_index()
#####################################################################
UL_User_ThrM10_BaseLine=rd4_Before[((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']<=UL_User_Thr_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']<=UL_User_Thr_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']<=UL_User_Thr_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
UL_User_ThrM10_BaseLine_df=pd.DataFrame(UL_User_ThrM10_BaseLine).reset_index()

# %%
UL_User_Thr100_Target=rd4_After[((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_H_Th1)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_E_Th1)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_N_Th1)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
UL_User_Thr100_Target_df=pd.DataFrame(UL_User_Thr100_Target).reset_index()
#####################################################################
UL_User_Thr90_Target=(rd4_After[((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_H_Th2)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_E_Th2)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_N_Th2)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-UL_User_Thr100_Target
UL_User_Thr90_Target_df=pd.DataFrame(UL_User_Thr90_Target).reset_index()
#####################################################################
UL_User_Thr80_Target=(rd4_After[((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_H_Th3)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_E_Th3)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_N_Th3)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(UL_User_Thr100_Target+UL_User_Thr90_Target)
UL_User_Thr80_Target_df=pd.DataFrame(UL_User_Thr80_Target).reset_index()
#####################################################################
UL_User_Thr50_Target=(rd4_After[((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']>UL_User_Thr_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(UL_User_Thr100_Target+UL_User_Thr90_Target+UL_User_Thr80_Target)
UL_User_Thr50_Target_df=pd.DataFrame(UL_User_Thr50_Target).reset_index()
#####################################################################
UL_User_ThrM10_Target=rd4_After[((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']<=UL_User_Thr_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']<=UL_User_Thr_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['Average_UPlink_User_Throughput(Mbit/s)per 5MHz']<=UL_User_Thr_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
UL_User_ThrM10_Target_df=pd.DataFrame(UL_User_ThrM10_Target).reset_index()

# %%
DL_Cell_SE100_BaseLine=rd4_Before[((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_H_Th1)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_E_Th1)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_N_Th1)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
DL_Cell_SE100_BaseLine_df=pd.DataFrame(DL_Cell_SE100_BaseLine).reset_index()
#####################################################################
DL_Cell_SE90_BaseLine=(rd4_Before[((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_H_Th2)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_E_Th2)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_N_Th2)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-DL_Cell_SE100_BaseLine
DL_Cell_SE90_BaseLine_df=pd.DataFrame(DL_Cell_SE90_BaseLine).reset_index()
#####################################################################
DL_Cell_SE80_BaseLine=(rd4_Before[((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_H_Th3)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_E_Th3)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_N_Th3)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(DL_Cell_SE100_BaseLine+DL_Cell_SE90_BaseLine)
DL_Cell_SE80_BaseLine_df=pd.DataFrame(DL_Cell_SE80_BaseLine).reset_index()
#####################################################################
DL_Cell_SE50_BaseLine=(rd4_Before[((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(DL_Cell_SE100_BaseLine+DL_Cell_SE90_BaseLine+DL_Cell_SE80_BaseLine)
DL_Cell_SE50_BaseLine_df=pd.DataFrame(DL_Cell_SE50_BaseLine).reset_index()
#####################################################################
DL_Cell_SEM10_BaseLine=rd4_Before[((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']<=DL_Cell_SE_H_Th4)&(rd4_Before['Vendor']=='Huawei'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']<=DL_Cell_SE_E_Th4)&(rd4_Before['Vendor']=='Ericsson'))
               | ((rd4_Before['DL Cell Spectoral Efficiency (bps/Hz)']<=DL_Cell_SE_N_Th4)&(rd4_Before['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
DL_Cell_SEM10_BaseLine_df=pd.DataFrame(DL_Cell_SEM10_BaseLine).reset_index()

# %%
DL_Cell_SE100_Target=rd4_After[((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_H_Th1)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_E_Th1)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_N_Th1)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
DL_Cell_SE100_Target_df=pd.DataFrame(DL_Cell_SE100_Target).reset_index()
#####################################################################
DL_Cell_SE90_Target=(rd4_After[((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_H_Th2)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_E_Th2)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_N_Th2)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-DL_Cell_SE100_Target
DL_Cell_SE90_Target_df=pd.DataFrame(DL_Cell_SE90_Target).reset_index()
#####################################################################
DL_Cell_SE80_Target=(rd4_After[((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_H_Th3)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_E_Th3)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_N_Th3)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(DL_Cell_SE100_Target+DL_Cell_SE90_Target)
DL_Cell_SE80_Target_df=pd.DataFrame(DL_Cell_SE80_Target).reset_index()
#####################################################################
DL_Cell_SE50_Target=(rd4_After[((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']>DL_Cell_SE_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count())-(DL_Cell_SE100_Target+DL_Cell_SE90_Target+DL_Cell_SE80_Target)
DL_Cell_SE50_Target_df=pd.DataFrame(DL_Cell_SE50_Target).reset_index()
#####################################################################
DL_Cell_SEM10_Target=rd4_After[((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']<=DL_Cell_SE_H_Th4)&(rd4_After['Vendor']=='Huawei'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']<=DL_Cell_SE_E_Th4)&(rd4_After['Vendor']=='Ericsson'))
               | ((rd4_After['DL Cell Spectoral Efficiency (bps/Hz)']<=DL_Cell_SE_N_Th4)&(rd4_After['Vendor']=='Nokia'))].groupby('Index')['eNodeB'].count()
DL_Cell_SEM10_Target_df=pd.DataFrame(DL_Cell_SEM10_Target).reset_index()

# %%
Dashboard_Final=Dashboard_Final.merge(PS_CSSR100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(PS_CSSR90_BaseLine_df,on='Index',suffixes=('PS_CSSR100_BaseLine','PS_CSSR90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(PS_CSSR80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(PS_CSSR50_BaseLine_df,on='Index',suffixes=('PS_CSSR80_BaseLine','PS_CSSR50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(PS_CSSRM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBPS_CSSRM10_Baseline'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(PS_CSSR100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(PS_CSSR90_Target_df,on='Index',suffixes=('PS_CSSR100_Target','PS_CSSR90_Target'))
Dashboard_Final=Dashboard_Final.merge(PS_CSSR80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(PS_CSSR50_Target_df,on='Index',suffixes=('PS_CSSR80_Target','PS_CSSR50_Target'))
Dashboard_Final=Dashboard_Final.merge(PS_CSSRM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBPS_CSSRM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(HOSR100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(HOSR90_BaseLine_df,on='Index',suffixes=('HOSR100_BaseLine','HOSR90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(HOSR80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(HOSR50_BaseLine_df,on='Index',suffixes=('HOSR80_BaseLine','HOSR50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(HOSRM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBHOSRM10_BaseLine'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(HOSR100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(HOSR90_Target_df,on='Index',suffixes=('HOSR100_Target','HOSR90_Target'))
Dashboard_Final=Dashboard_Final.merge(HOSR80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(HOSR50_Target_df,on='Index',suffixes=('HOSR80_Target','HOSR50_Target'))
Dashboard_Final=Dashboard_Final.merge(HOSRM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBHOSRM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(DL_User_Thr100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(DL_User_Thr90_BaseLine_df,on='Index',suffixes=('DL_User_Thr100_BaseLine','DL_User_Thr90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(DL_User_Thr80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(DL_User_Thr50_BaseLine_df,on='Index',suffixes=('DL_User_Thr80_BaseLine','DL_User_Thr50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(DL_User_ThrM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBDL_User_ThrM10_BaseLine'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(DL_User_Thr100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(DL_User_Thr90_Target_df,on='Index',suffixes=('DL_User_Thr100_Target','DL_User_Thr90_Target'))
Dashboard_Final=Dashboard_Final.merge(DL_User_Thr80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(DL_User_Thr50_Target_df,on='Index',suffixes=('DL_User_Thr80_Target','DL_User_Thr50_Target'))
Dashboard_Final=Dashboard_Final.merge(DL_User_ThrM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBDL_User_ThrM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(UL_User_Thr100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(UL_User_Thr90_BaseLine_df,on='Index',suffixes=('UL_User_Thr100_BaseLine','UL_User_Thr90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(UL_User_Thr80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(UL_User_Thr50_BaseLine_df,on='Index',suffixes=('UL_User_Thr80_BaseLine','UL_User_Thr50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(UL_User_ThrM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBUL_User_ThrM10_BaseLine'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(UL_User_Thr100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(UL_User_Thr90_Target_df,on='Index',suffixes=('UL_User_Thr100_Target','UL_User_Thr90_Target'))
Dashboard_Final=Dashboard_Final.merge(UL_User_Thr80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(UL_User_Thr50_Target_df,on='Index',suffixes=('UL_User_Thr80_Target','UL_User_Thr50_Target'))
Dashboard_Final=Dashboard_Final.merge(UL_User_ThrM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBUL_User_ThrM10_Target'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SE100_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SE90_BaseLine_df,on='Index',suffixes=('DL_Cell_SE100_BaseLine','DL_Cell_SE90_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SE80_BaseLine_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SE50_BaseLine_df,on='Index',suffixes=('DL_Cell_SE80_BaseLine','DL_Cell_SE50_BaseLine'))
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SEM10_BaseLine_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBDL_Cell_SEM10_BaseLine'},inplace=True)

# %%
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SE100_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SE90_Target_df,on='Index',suffixes=('DL_Cell_SE100_Target','DL_Cell_SE90_Target'))
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SE80_Target_df,on='Index')
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SE50_Target_df,on='Index',suffixes=('DL_Cell_SE80_Target','DL_Cell_SE50_Target'))
Dashboard_Final=Dashboard_Final.merge(DL_Cell_SEM10_Target_df,on='Index')
Dashboard_Final.rename(columns={'eNodeB':'eNodeBDL_Cell_SEM10_Target'},inplace=True)

# %%
Dashboard_Final['eNodeBPS_CSSR100_BaseLine_Percentage']=100*Dashboard_Final['eNodeBPS_CSSR100_BaseLine']/Dashboard_Final['LTE_Service_Success_Rate_Baseline']
Dashboard_Final['eNodeBPS_CSSR90_BaseLine_Percentage']=100*Dashboard_Final['eNodeBPS_CSSR90_BaseLine']/Dashboard_Final['LTE_Service_Success_Rate_Baseline']
Dashboard_Final['eNodeBPS_CSSR80_BaseLine_Percentage']=100*Dashboard_Final['eNodeBPS_CSSR80_BaseLine']/Dashboard_Final['LTE_Service_Success_Rate_Baseline']
Dashboard_Final['eNodeBPS_CSSR50_BaseLine_Percentage']=100*Dashboard_Final['eNodeBPS_CSSR50_BaseLine']/Dashboard_Final['LTE_Service_Success_Rate_Baseline']
Dashboard_Final['eNodeBPS_CSSRM10_BaseLine_Percentage']=100*Dashboard_Final['eNodeBPS_CSSRM10_Baseline']/Dashboard_Final['LTE_Service_Success_Rate_Baseline']

# %%
Dashboard_Final['eNodeBPS_CSSR100_Target_Percentage']=100*Dashboard_Final['eNodeBPS_CSSR100_Target']/Dashboard_Final['LTE_Service_Success_Rate_Target']
Dashboard_Final['eNodeBPS_CSSR90_Target_Percentage']=100*Dashboard_Final['eNodeBPS_CSSR90_Target']/Dashboard_Final['LTE_Service_Success_Rate_Target']
Dashboard_Final['eNodeBPS_CSSR80_Target_Percentage']=100*Dashboard_Final['eNodeBPS_CSSR80_Target']/Dashboard_Final['LTE_Service_Success_Rate_Target']
Dashboard_Final['eNodeBPS_CSSR50_Target_Percentage']=100*Dashboard_Final['eNodeBPS_CSSR50_Target']/Dashboard_Final['LTE_Service_Success_Rate_Target']
Dashboard_Final['eNodeBPS_CSSRM10_Target_Percentage']=100*Dashboard_Final['eNodeBPS_CSSRM10_Target']/Dashboard_Final['LTE_Service_Success_Rate_Target']

# %%
Dashboard_Final['eNodeBHOSR100_BaseLine_Percentage']=100*Dashboard_Final['eNodeBHOSR100_BaseLine']/Dashboard_Final['Handover_Execution_Rate_Baseline']
Dashboard_Final['eNodeBHOSR90_BaseLine_Percentage']=100*Dashboard_Final['eNodeBHOSR90_BaseLine']/Dashboard_Final['Handover_Execution_Rate_Baseline']
Dashboard_Final['eNodeBHOSR80_BaseLine_Percentage']=100*Dashboard_Final['eNodeBHOSR80_BaseLine']/Dashboard_Final['Handover_Execution_Rate_Baseline']
Dashboard_Final['eNodeBHOSR50_BaseLine_Percentage']=100*Dashboard_Final['eNodeBHOSR50_BaseLine']/Dashboard_Final['Handover_Execution_Rate_Baseline']
Dashboard_Final['eNodeBHOSRM10_BaseLine_Percentage']=100*Dashboard_Final['eNodeBHOSRM10_BaseLine']/Dashboard_Final['Handover_Execution_Rate_Baseline']

# %%
Dashboard_Final['eNodeBHOSR100_Target_Percentage']=100*Dashboard_Final['eNodeBHOSR100_Target']/Dashboard_Final['Handover_Execution_Rate_Target']
Dashboard_Final['eNodeBHOSR90_Target_Percentage']=100*Dashboard_Final['eNodeBHOSR90_Target']/Dashboard_Final['Handover_Execution_Rate_Target']
Dashboard_Final['eNodeBHOSR80_Target_Percentage']=100*Dashboard_Final['eNodeBHOSR80_Target']/Dashboard_Final['Handover_Execution_Rate_Target']
Dashboard_Final['eNodeBHOSR50_Target_Percentage']=100*Dashboard_Final['eNodeBHOSR50_Target']/Dashboard_Final['Handover_Execution_Rate_Target']
Dashboard_Final['eNodeBHOSRM10_Target_Percentage']=100*Dashboard_Final['eNodeBHOSRM10_Target']/Dashboard_Final['Handover_Execution_Rate_Target']

# %%
Dashboard_Final['eNodeBDL_User_Thr100_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_User_Thr100_BaseLine']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Baseline']
Dashboard_Final['eNodeBDL_User_Thr90_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_User_Thr90_BaseLine']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Baseline']
Dashboard_Final['eNodeBDL_User_Thr80_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_User_Thr80_BaseLine']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Baseline']
Dashboard_Final['eNodeBDL_User_Thr50_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_User_Thr50_BaseLine']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Baseline']
Dashboard_Final['eNodeBDL_User_ThrM10_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_User_ThrM10_BaseLine']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Baseline']

# %%
Dashboard_Final['eNodeBDL_User_Thr100_Target_Percentage']=100*Dashboard_Final['eNodeBDL_User_Thr100_Target']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Target']
Dashboard_Final['eNodeBDL_User_Thr90_Target_Percentage']=100*Dashboard_Final['eNodeBDL_User_Thr90_Target']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Target']
Dashboard_Final['eNodeBDL_User_Thr80_Target_Percentage']=100*Dashboard_Final['eNodeBDL_User_Thr80_Target']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Target']
Dashboard_Final['eNodeBDL_User_Thr50_Target_Percentage']=100*Dashboard_Final['eNodeBDL_User_Thr50_Target']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Target']
Dashboard_Final['eNodeBDL_User_ThrM10_Target_Percentage']=100*Dashboard_Final['eNodeBDL_User_ThrM10_Target']/Dashboard_Final['Average_Downlink_User_Throughput(Mbit/s)per 5MHz_Target']

# %%
Dashboard_Final['eNodeBUL_User_Thr100_BaseLine_Percentage']=100*Dashboard_Final['eNodeBUL_User_Thr100_BaseLine']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Baseline']
Dashboard_Final['eNodeBUL_User_Thr90_BaseLine_Percentage']=100*Dashboard_Final['eNodeBUL_User_Thr90_BaseLine']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Baseline']
Dashboard_Final['eNodeBUL_User_Thr80_BaseLine_Percentage']=100*Dashboard_Final['eNodeBUL_User_Thr80_BaseLine']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Baseline']
Dashboard_Final['eNodeBUL_User_Thr50_BaseLine_Percentage']=100*Dashboard_Final['eNodeBUL_User_Thr50_BaseLine']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Baseline']
Dashboard_Final['eNodeBUL_User_ThrM10_BaseLine_Percentage']=100*Dashboard_Final['eNodeBUL_User_ThrM10_BaseLine']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Baseline']

# %%
Dashboard_Final['eNodeBUL_User_Thr100_Target_Percentage']=100*Dashboard_Final['eNodeBUL_User_Thr100_Target']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Target']
Dashboard_Final['eNodeBUL_User_Thr90_Target_Percentage']=100*Dashboard_Final['eNodeBUL_User_Thr90_Target']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Target']
Dashboard_Final['eNodeBUL_User_Thr80_Target_Percentage']=100*Dashboard_Final['eNodeBUL_User_Thr80_Target']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Target']
Dashboard_Final['eNodeBUL_User_Thr50_Target_Percentage']=100*Dashboard_Final['eNodeBUL_User_Thr50_Target']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Target']
Dashboard_Final['eNodeBUL_User_ThrM10_Target_Percentage']=100*Dashboard_Final['eNodeBUL_User_ThrM10_Target']/Dashboard_Final['Average_UPlink_User_Throughput(Mbit/s)per 5MHz_Target']

# %%
Dashboard_Final['eNodeBDL_Cell_SE100_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SE100_BaseLine']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Baseline']
Dashboard_Final['eNodeBDL_Cell_SE90_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SE90_BaseLine']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Baseline']
Dashboard_Final['eNodeBDL_Cell_SE80_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SE80_BaseLine']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Baseline']
Dashboard_Final['eNodeBDL_Cell_SE50_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SE50_BaseLine']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Baseline']
Dashboard_Final['eNodeBDL_Cell_SEM10_BaseLine_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SEM10_BaseLine']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Baseline']

# %%
Dashboard_Final['eNodeBDL_Cell_SE100_Target_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SE100_Target']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Target']
Dashboard_Final['eNodeBDL_Cell_SE90_Target_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SE90_Target']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Target']
Dashboard_Final['eNodeBDL_Cell_SE80_Target_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SE80_Target']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Target']
Dashboard_Final['eNodeBDL_Cell_SE50_Target_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SE50_Target']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Target']
Dashboard_Final['eNodeBDL_Cell_SEM10_Target_Percentage']=100*Dashboard_Final['eNodeBDL_Cell_SEM10_Target']/Dashboard_Final['DL Cell Spectoral Efficiency (bps/Hz)_Target']

# %%
Dashboard_Final['Mark_PS_CSSR_Baseline']=Dashboard_Final['eNodeBPS_CSSR100_BaseLine_Percentage']*1+Dashboard_Final['eNodeBPS_CSSR90_BaseLine_Percentage']*0.9+Dashboard_Final['eNodeBPS_CSSR80_BaseLine_Percentage']*0.8+Dashboard_Final['eNodeBPS_CSSR50_BaseLine_Percentage']*0.5+Dashboard_Final['eNodeBPS_CSSRM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_PS_CSSR_Target']=Dashboard_Final['eNodeBPS_CSSR100_Target_Percentage']*1+Dashboard_Final['eNodeBPS_CSSR90_Target_Percentage']*0.9+Dashboard_Final['eNodeBPS_CSSR80_Target_Percentage']*0.8+Dashboard_Final['eNodeBPS_CSSR50_Target_Percentage']*0.5+Dashboard_Final['eNodeBPS_CSSRM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_HOSR_Baseline']=Dashboard_Final['eNodeBHOSR100_BaseLine_Percentage']*1+Dashboard_Final['eNodeBHOSR90_BaseLine_Percentage']*0.9+Dashboard_Final['eNodeBHOSR80_BaseLine_Percentage']*0.8+Dashboard_Final['eNodeBHOSR50_BaseLine_Percentage']*0.5+Dashboard_Final['eNodeBHOSRM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_HOSR_Target']=Dashboard_Final['eNodeBHOSR100_Target_Percentage']*1+Dashboard_Final['eNodeBHOSR90_Target_Percentage']*0.9+Dashboard_Final['eNodeBHOSR80_Target_Percentage']*0.8+Dashboard_Final['eNodeBHOSR50_Target_Percentage']*0.5+Dashboard_Final['eNodeBHOSRM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_DL_User_Thr_Baseline']=Dashboard_Final['eNodeBDL_User_Thr100_BaseLine_Percentage']*1+Dashboard_Final['eNodeBDL_User_Thr90_BaseLine_Percentage']*0.9+Dashboard_Final['eNodeBDL_User_Thr80_BaseLine_Percentage']*0.8+Dashboard_Final['eNodeBDL_User_Thr50_BaseLine_Percentage']*0.5+Dashboard_Final['eNodeBDL_User_ThrM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_DL_User_Thr_Target']=Dashboard_Final['eNodeBDL_User_Thr100_Target_Percentage']*1+Dashboard_Final['eNodeBDL_User_Thr90_Target_Percentage']*0.9+Dashboard_Final['eNodeBDL_User_Thr80_Target_Percentage']*0.8+Dashboard_Final['eNodeBDL_User_Thr50_Target_Percentage']*0.5+Dashboard_Final['eNodeBDL_User_ThrM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_UL_User_Thr_Baseline']=Dashboard_Final['eNodeBUL_User_Thr100_BaseLine_Percentage']*1+Dashboard_Final['eNodeBUL_User_Thr90_BaseLine_Percentage']*0.9+Dashboard_Final['eNodeBUL_User_Thr80_BaseLine_Percentage']*0.8+Dashboard_Final['eNodeBUL_User_Thr50_BaseLine_Percentage']*0.5+Dashboard_Final['eNodeBUL_User_ThrM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_UL_User_Thr_Target']=Dashboard_Final['eNodeBUL_User_Thr100_Target_Percentage']*1+Dashboard_Final['eNodeBUL_User_Thr90_Target_Percentage']*0.9+Dashboard_Final['eNodeBUL_User_Thr80_Target_Percentage']*0.8+Dashboard_Final['eNodeBUL_User_Thr50_Target_Percentage']*0.5+Dashboard_Final['eNodeBUL_User_ThrM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['Mark_DL_Cell_SE_Baseline']=Dashboard_Final['eNodeBDL_Cell_SE100_BaseLine_Percentage']*1+Dashboard_Final['eNodeBDL_Cell_SE90_BaseLine_Percentage']*0.9+Dashboard_Final['eNodeBDL_Cell_SE80_BaseLine_Percentage']*0.8+Dashboard_Final['eNodeBDL_Cell_SE50_BaseLine_Percentage']*0.5+Dashboard_Final['eNodeBDL_Cell_SEM10_BaseLine_Percentage']*(-0.1)
Dashboard_Final['Mark_DL_Cell_SE_Target']=Dashboard_Final['eNodeBDL_Cell_SE100_Target_Percentage']*1+Dashboard_Final['eNodeBDL_Cell_SE90_Target_Percentage']*0.9+Dashboard_Final['eNodeBDL_Cell_SE80_Target_Percentage']*0.8+Dashboard_Final['eNodeBDL_Cell_SE50_Target_Percentage']*0.5+Dashboard_Final['eNodeBDL_Cell_SEM10_Target_Percentage']*(-0.1)

# %%
Dashboard_Final['PS_CSSR_Growth']=100*(Dashboard_Final['Mark_PS_CSSR_Target']-Dashboard_Final['Mark_PS_CSSR_Baseline'])/Dashboard_Final['Mark_PS_CSSR_Baseline']
Dashboard_Final['HOSR_Growth']=100*(Dashboard_Final['Mark_HOSR_Target']-Dashboard_Final['Mark_HOSR_Baseline'])/Dashboard_Final['Mark_HOSR_Baseline']
Dashboard_Final['DL_User_Thr_Growth']=100*(Dashboard_Final['Mark_DL_User_Thr_Target']-Dashboard_Final['Mark_DL_User_Thr_Baseline'])/Dashboard_Final['Mark_DL_User_Thr_Baseline']
Dashboard_Final['UL_User_Thr_Growth']=100*(Dashboard_Final['Mark_UL_User_Thr_Target']-Dashboard_Final['Mark_UL_User_Thr_Baseline'])/Dashboard_Final['Mark_UL_User_Thr_Baseline']
Dashboard_Final['DL_Cell_SE_Growth']=100*(Dashboard_Final['Mark_DL_Cell_SE_Target']-Dashboard_Final['Mark_DL_Cell_SE_Baseline'])/Dashboard_Final['Mark_DL_Cell_SE_Baseline']

# %%
Dashboard_Final.loc[Dashboard_Final['PS_CSSR_Growth']<=-10,'PS_CSSR_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['PS_CSSR_Growth']>=10,'PS_CSSR_Growth']=10
Dashboard_Final.loc[Dashboard_Final['HOSR_Growth']<=-10,'HOSR_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['HOSR_Growth']>=10,'HOSR_Growth']=10
Dashboard_Final.loc[Dashboard_Final['DL_User_Thr_Growth']<=-10,'DL_User_Thr_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['DL_User_Thr_Growth']>=10,'DL_User_Thr_Growth']=10
Dashboard_Final.loc[Dashboard_Final['UL_User_Thr_Growth']<=-10,'UL_User_Thr_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['UL_User_Thr_Growth']>=10,'UL_User_Thr_Growth']=10
Dashboard_Final.loc[Dashboard_Final['DL_Cell_SE_Growth']<=-10,'DL_Cell_SE_Growth']=-10
Dashboard_Final.loc[Dashboard_Final['DL_Cell_SE_Growth']>=10,'DL_Cell_SE_Growth']=10

# %%
Dashboard_Final['PS_CSSR_Score']=(0.9*Dashboard_Final['Mark_PS_CSSR_Target']+Dashboard_Final['PS_CSSR_Growth'])/100
Dashboard_Final['HOSR_Score']=(0.9*Dashboard_Final['Mark_HOSR_Target']+Dashboard_Final['HOSR_Growth'])/100
Dashboard_Final['DL_User_Thr_Score']=(0.9*Dashboard_Final['Mark_DL_User_Thr_Target']+Dashboard_Final['DL_User_Thr_Growth'])/100
Dashboard_Final['UL_User_Thr_Score']=(0.9*Dashboard_Final['Mark_UL_User_Thr_Target']+Dashboard_Final['UL_User_Thr_Growth'])/100
Dashboard_Final['DL_Cell_SE_Score']=(0.9*Dashboard_Final['Mark_DL_Cell_SE_Target']+Dashboard_Final['DL_Cell_SE_Growth'])/100

# %%
y=(Dashboard_Final['PS_CSSR_Score']-min(Dashboard_Final['PS_CSSR_Score']))/(max(Dashboard_Final['PS_CSSR_Score'])-min(Dashboard_Final['PS_CSSR_Score']))
Dashboard_Final['PS_CSSR_Score_NO']=(0.5+0.5*y)
y1=(Dashboard_Final['HOSR_Score']-min(Dashboard_Final['HOSR_Score']))/(max(Dashboard_Final['HOSR_Score'])-min(Dashboard_Final['HOSR_Score']))
Dashboard_Final['HOSR_Score_NO']=(0.5+0.5*y1)
y3=(Dashboard_Final['DL_User_Thr_Score']-min(Dashboard_Final['DL_User_Thr_Score']))/(max(Dashboard_Final['DL_User_Thr_Score'])-min(Dashboard_Final['DL_User_Thr_Score']))
Dashboard_Final['DL_User_Thr_Score_NO']=(0.5+0.5*y3)
y2=(Dashboard_Final['UL_User_Thr_Score']-min(Dashboard_Final['UL_User_Thr_Score']))/(max(Dashboard_Final['UL_User_Thr_Score'])-min(Dashboard_Final['UL_User_Thr_Score']))
Dashboard_Final['UL_User_Thr_Score_NO']=(0.5+0.5*y2)
y4=(Dashboard_Final['DL_Cell_SE_Score']-min(Dashboard_Final['DL_Cell_SE_Score']))/(max(Dashboard_Final['DL_Cell_SE_Score'])-min(Dashboard_Final['DL_Cell_SE_Score']))
Dashboard_Final['DL_Cell_SE_Score_NO']=(0.5+0.5*y4)

# %%
Dashboard_Final.to_excel('4G_Result_Mehr.xlsx')

# %%
AG = rd4_Before[rd4_Before['Index']=='AG']
AG.to_excel('AG.xlsx')
